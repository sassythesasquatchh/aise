# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import time
import torch.nn as nn
torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import torch
#       4 from torch.utils.data import DataLoader
#       5 import time
#
# File c:\Users\patri\OneDrive\Patricks OneDrive Share\Documents\ETHZ\Fruhling_23\AISE\venv\Lib\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "c:\Users\patri\OneDrive\Patricks OneDrive Share\Documents\ETHZ\Fruhling_23\AISE\venv\Lib\site-packages\torch\lib\cudnn_cnn_infer64_8.dll" or one of its dependencies.

# %% [markdown]
# # Basic theory and problem setup
# Consider the one-dimensional heat equation:
#
# $$
# u_t(t, x) = u_{xx}(t, x), \quad t\in[0,T], ~x\in [-1,1]
# $$
#
#
# with zero Dirichlet boundary conditions
#
# $$
# u_b(t, -1)=u_b(t,1)=0,
# $$
#
# and initial condition
#
# $$
# u(x, 0) = u_0(x) = - \sin(\pi x)
# $$
#
# We want to obtain an approximate solution of the heat equation $u : [0,T]\times[-1,1] \mapsto \mathbb{R}$ with physics informed neural networks (PINNs).
#
# To do so, we approximate the underlying solution with a feedforward dense neural network with tunable parameters $\theta$:
#
# $$
# u_\theta(t,x) \approx u(t,x)
# $$
# Define the following residuals:
#
#    - Interior residual given by,
#
#    $$r_{int,\theta}(t, x):=  u_{\theta, t}(x,t) - u_{\theta, xx}(x,t), \quad \forall ~t \in [0,T],~ x \in [-1,1].$$
#
#
#
#
#    - Spatial boundary residual given by,
#
#         $$r_{sb,\theta}(t,-1):= u_{\theta}(t,-1)- u_b(t,-1), \quad r_{sb,\theta}(t,1):= u_{\theta}(t,1)- u_b(t,1), \quad \forall t \in (0,T].$$
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x):= u_{\theta}(x,0) - u_0(x), \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int}(\theta) = \int_{[0,T]\times[-1,1]}r_{int,\theta}^2(t, x) dtdx, \quad
# L_{sb}(\theta) = \int_{[0,T]}r_{sb,\theta}^2(t,-1) dt + \int_{[0,T]}r_{sb,\theta}^2(t,1)dt, \quad
# L_{tb}(\theta) = \int_{[-1,1]}r_{tb,\theta}^2(x) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t)_n \in D_T,
# $$
#
# $$
# S_{sb, -1} =\{t_n, u_b(t_n,-1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{sb, 1} =\{t_n, u_b(t_n,1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{tb}=\{x_n, u_0(x_n)\}\quad  1 \leq n \leq N_{tb}, x_n \in [-1,1].
# $$
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences.
#
# $$
# L_{int}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta}^2(y_n), \quad
# L_{sb}(\theta) = \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,-1) + \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,1), \quad
# L_{tb}(\theta) = \frac{1}{N_{tb}}\sum_{i=1}^{N_{tb}}r_{tb,\theta}^2(x_n)
# $$
#
# and solve the following minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_u(\theta) = L_{tb}(\theta) + L_{sb}(\theta)
# $$

# %% [markdown]
# # Your task: Solve the $1D$ heat equation using PINNs
#
# You will have to implement the following
#
# *  `NNAnsatz` a neural net approximator for the solution of the heat equation.
# *   Missing functionality in the `PINNTrainer`, namely:
#     *   `PINNTrainer.compute_pde_residual` to compute the PDE loss on your predictions.
#     *   `PINNTrainer.compute_loss` to aggregate all the residuals into a single weighted loss.
#
# Use `torch.autograd.grad` to compute gradients, second derivatives -- some basic examples can be found [here](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html). Make sure the gradients you compute are attached to the computational graph so that you can backpropagate through them.
#
#
# Follow the `TODOs`.

# %%
class NNAnsatz(torch.nn.Module):
  def __init__(self,
               input_dimension,
               output_dimension,
               n_hidden_layers,
               hidden_size):


    super(NNAnsatz, self).__init__()

    self.input_layer=nn.Linear(input_dimension, hidden_size)

    self.hidden_layers = nn.ModuleList()
    for _ in range(n_hidden_layers):
      self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))

    self.output_layer=nn.Linear(hidden_size, output_dimension)

    self.activation = nn.Tanh()


  def forward(self, x):
    # TODO: Do a forward pass on `x`.
    x=self.activation(self.input_layer(x))

    for hidden_layer in self.hidden_layers:
      x = self.activation(hidden_layer(x))

    x=self.activation(self.output_layer(x))

    return x

# %%
class PINNTrainer:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_

        # Extrema of the solution domain (t, x) in [0,0.1] x [-1,1]
        self.domain_extrema = torch.tensor([[0, 1.],  # Time dimension
                                            [0., 1.]])  # Space dimension

        # Number of space dimensions
        self.space_dimensions = 1

        # Parameter to balance role of data and PDE
        self.lambda_u = 10

        # F Dense NN to approximate the solution of the underlying heat equation
        # TODO: Write the `NNAnsatz` class to be a feed-forward neural net
        # that you'll train to approximate your solution.
        self.approximate_solution = NNAnsatz(input_dimension=self.domain_extrema.shape[0],
                                             output_dimension=2,
                                             n_hidden_layers=4,
                                             hidden_size=20)

        # TODO: Setup optimizer.
        self.optimizer = torch.optim.Adam(self.approximate_solution.parameters(),
                                          lr=float(0.001))

        # Generator of Sobol sequences.
        self.soboleng = torch.quasirandom.SobolEngine(
            dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = (
            self.assemble_datasets())

    ############################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return (
            tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0])
             + self.domain_extrema[:, 0])

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, x):
        # input is (x)*n and the output is (T_s, T_f)*n
        # Initial condition is 1 fr T_s and t_f
        return torch.ones(len(x),2)

    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]

        u = -torch.exp(-np.pi ** 2 * t) * torch.sin(np.pi * x)
        return u

    ############################################################################
    # Function returning the input-output tensor required to
    # assemble the training set S_tb corresponding to the temporal boundary.
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))

        # Assigns the value t0 to every element of the first column of input_tb
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        # Creates a column vector containing the solution at each temporal boundary point,
        # based on the initial condition
        output_tb = self.initial_condition(input_tb[:, 1])

        # input_tb has points [t0,x], with x being taken across the whole spatial domain
        # output_tb has points [u_S, u_f], the value of the initial condition at the corresponding
        # spatial coordinate
        return input_tb, output_tb

    # Function returning the input-output tensor required to
    # assemble the training set S_sb corresponding to the spatial boundary.
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        # spatial boundary conditions at the lower spatial extrema
        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        # spatial boundary conditions at the upper spatial extrema
        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        # value of the solution at the lower spatial extrema
        # if the value is constrained by PDE only (eg. neumann BCs),
        # put 0
        output_sb_0 = torch.zeros((input_sb.shape[0], 1))

        # value of the solution at the upper spatial extrema
        # if the value is constrained by PDE only (eg. neumann BCs),
        # put 0
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return (
            torch.cat([input_sb_0, input_sb_L], 0),
            torch.cat([output_sb_0, output_sb_L], 0)
        )

    # Function returning the input-output tensor required to assemble
    # the training set S_int corresponding to the interior domain
    # where the PDE is enforced.
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()   # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()         # S_int

        training_set_sb = DataLoader(
            torch.utils.data.TensorDataset(input_sb, output_sb),
            batch_size=2 * self.space_dimensions*self.n_sb, shuffle=False)
        training_set_tb = DataLoader(
            torch.utils.data.TensorDataset(input_tb, output_tb),
            batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(
            torch.utils.data.TensorDataset(input_int, output_int),
            batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ############################################################################
    # Function to compute the terms required in the definition of
    # the `TEMPORAL` boundary residual.
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition
    # of the `SPATIAL` boundary residual.
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)
        # `grad` computes the gradient of a SCALAR function `L` w.r.t
        # some input (n x m) tensor  [[x1, y1], ...,[xn ,yn]] (here `m` = 2).
        #
        # it returns grad_L = [[dL/dx1, dL/dy1]...,[dL/dxn, dL/dyn]]
        # NOTO: pytorch considers a tensor [u1, u2,u3, ... ,un] a vector
        # whereas `sum_u = u1 + u2 + u3 + u4 + ... + un` as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2], ...]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un) /dxi ==
        #  d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi == dui / dxi.

        # TODO: compute `grad_u` w.r.t (t, x) (time + 1D space).
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]

        # TODO: Extract time and space derivative at all input points.
        grad_u_t = grad_u[:,0]
        grad_u_x = grad_u[:,1]

        # TODO: Compute `grads` again across the spatial dimension --
        # here you should reuse something you just computed.
        grad_u_xx = torch.autograd.grad(
            grad_u_x.sum(),input_int,create_graph=True)[0][:,1]

        # Compute the residual term you're getting.
        residual = grad_u_t - grad_u_xx
        return residual.reshape(-1,)

    # Function to compute the total loss (weighted sum of spatial boundary loss,
    # temporal boundary loss and interior loss).
    def compute_loss(
        self, inp_train_sb, u_train_sb,
        inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])

        # TODO: Compute interior PDE residual.
        r_int = self.compute_pde_residual(inp_train_int)

        # TOOD: Compute spatial boundary residual.
        r_sb = u_train_sb-u_pred_sb

        # TODO: Compute temporal boundary residual
        r_tb = u_train_tb - u_pred_tb

        # TODO: Compute losses based on these residuals.
        loss_sb = torch.mean(r_sb**2)
        loss_tb = torch.mean(r_tb**2)
        loss_int = torch.mean(r_int**2)

        loss_u = loss_sb + loss_tb
        loss = torch.log10(self.lambda_u * (loss_sb + loss_tb) + loss_int)
        if verbose:
            print(
               "Total loss: ",round(loss.item(), 4),
               "| PDE Loss: ", round(torch.log10(loss_u).item(), 4),
               "| Function Loss: ", round(torch.log10(loss_int).item(), 4)
          )

        return loss

    ############################################################################

    def fit(self, num_epochs, verbose):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose:
                print("################################ ",
                    epoch, " ################################")

            for j, inputs_and_outputs in enumerate(zip(self.training_set_sb,
                    self.training_set_tb,
                    self.training_set_int)):
                (
                      (inp_train_sb, u_train_sb),
                      (inp_train_tb, u_train_tb),
                      (inp_train_int, u_train_int)
                  ) = inputs_and_outputs

                def closure():
                    self.optimizer.zero_grad()
                    loss = self.compute_loss(
                        inp_train_sb,
                        u_train_sb,
                        inp_train_tb,
                        u_train_tb,
                        inp_train_int,
                        verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                self.optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ############################################################################
    def plot(self):
        inputs = self.soboleng.draw(100000)
        inputs = self.convert(inputs)

        output = self.approximate_solution(inputs).reshape(-1, )
        exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(
            inputs[:, 1].detach(), inputs[:, 0].detach(),
            c=exact_output.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(
            inputs[:, 1].detach(), inputs[:, 0].detach(), c=output.detach(),
            cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Solution")
        axs[1].set_title("Approximate Solution")

        plt.show()

        err = (
            torch.mean((output - exact_output) ** 2) /
            torch.mean(exact_output ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm: ", err.item(), "%")

# %% [markdown]
# # Setting up the training data
#
# Just familiarize yourself with how wo generate collocation points for the different types of residuals.

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi * x).

n_int = 256
n_sb = 64
n_tb = 64

pinn = PINNTrainer(n_int, n_sb, n_tb)

# %%
# Plot the input training points.
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.scatter(
    input_sb_[:, 1].detach().numpy(),
    input_sb_[:, 0].detach().numpy(),
    label="Boundary Points")
plt.scatter(
    input_int_[:, 1].detach().numpy(),
    input_int_[:, 0].detach().numpy(),
    label="Interior Points")
plt.scatter(
    input_tb_[:, 1].detach().numpy(),
    input_tb_[:, 0].detach().numpy(),
    label="Initial Points")

plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %% [markdown]
# # Training
#
# Train your network and ensure your loss is low, and that your predictions are qualitatively similar to the true solution (plots should look similar).

# %%
hist = pinn.fit(num_epochs=10000, verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# Streaming output truncated to the last 5000 lines.
# Total loss:  -2.6313 | PDE Loss:  -4.0937 | Function Loss:  -2.815
# ################################  7501  ################################
# Total loss:  -2.7127 | PDE Loss:  -4.139 | Function Loss:  -2.9167
# ################################  7502  ################################
# Total loss:  -2.9087 | PDE Loss:  -4.2977 | Function Loss:  -3.1365
# ################################  7503  ################################
# Total loss:  -2.7409 | PDE Loss:  -4.1023 | Function Loss:  -2.9888
# ################################  7504  ################################
# Total loss:  -3.1563 | PDE Loss:  -4.3586 | Function Loss:  -3.5853
# ################################  7505  ################################
# Total loss:  -2.6816 | PDE Loss:  -4.0174 | Function Loss:  -2.9504
# ################################  7506  ################################
# Total loss:  -2.8033 | PDE Loss:  -4.1474 | Function Loss:  -3.0651
# ################################  7507  ################################
# Total loss:  -2.8426 | PDE Loss:  -4.1094 | Function Loss:  -3.1807
# ################################  7508  ################################
# Total loss:  -2.8661 | PDE Loss:  -4.1764 | Function Loss:  -3.1581
# ################################  7509  ################################
# Total loss:  -2.8587 | PDE Loss:  -4.2005 | Function Loss:  -3.1225
# ################################  7510  ################################
# Total loss:  -2.9191 | PDE Loss:  -4.2742 | Function Loss:  -3.1721
# ################################  7511  ################################
# Total loss:  -2.8882 | PDE Loss:  -4.2573 | Function Loss:  -3.1304
# ################################  7512  ################################
# Total loss:  -2.9104 | PDE Loss:  -4.2369 | Function Loss:  -3.1873
# ################################  7513  ################################
# Total loss:  -2.8834 | PDE Loss:  -4.2599 | Function Loss:  -3.12
# ################################  7514  ################################
# Total loss:  -2.9983 | PDE Loss:  -4.3313 | Function Loss:  -3.2695
# ################################  7515  ################################
# Total loss:  -2.6887 | PDE Loss:  -4.0631 | Function Loss:  -2.9269
# ################################  7516  ################################
# Total loss:  -2.7681 | PDE Loss:  -4.1792 | Function Loss:  -2.9815
# ################################  7517  ################################
# Total loss:  -2.927 | PDE Loss:  -4.2015 | Function Loss:  -3.2562
# ################################  7518  ################################
# Total loss:  -2.8199 | PDE Loss:  -4.1436 | Function Loss:  -3.0993
# ################################  7519  ################################
# Total loss:  -3.0917 | PDE Loss:  -4.3073 | Function Loss:  -3.4993
# ################################  7520  ################################
# Total loss:  -2.7514 | PDE Loss:  -3.8897 | Function Loss:  -3.3158
# ################################  7521  ################################
# Total loss:  -3.1434 | PDE Loss:  -4.3455 | Function Loss:  -3.5727
# ################################  7522  ################################
# Total loss:  -2.4976 | PDE Loss:  -3.6307 | Function Loss:  -3.076
# ################################  7523  ################################
# Total loss:  -2.6075 | PDE Loss:  -3.7304 | Function Loss:  -3.2159
# ################################  7524  ################################
# Total loss:  -2.8372 | PDE Loss:  -4.0552 | Function Loss:  -3.2409
# ################################  7525  ################################
# Total loss:  -2.8249 | PDE Loss:  -3.9903 | Function Loss:  -3.3242
# ################################  7526  ################################
# Total loss:  -2.7704 | PDE Loss:  -3.9213 | Function Loss:  -3.3026
# ################################  7527  ################################
# Total loss:  -2.9606 | PDE Loss:  -4.1636 | Function Loss:  -3.3885
# ################################  7528  ################################
# Total loss:  -2.4861 | PDE Loss:  -3.5947 | Function Loss:  -3.1414
# ################################  7529  ################################
# Total loss:  -2.3435 | PDE Loss:  -3.4502 | Function Loss:  -3.0054
# ################################  7530  ################################
# Total loss:  -2.7585 | PDE Loss:  -3.9807 | Function Loss:  -3.1559
# ################################  7531  ################################
# Total loss:  -2.4128 | PDE Loss:  -3.5365 | Function Loss:  -3.0185
# ################################  7532  ################################
# Total loss:  -2.1395 | PDE Loss:  -3.2632 | Function Loss:  -2.7452
# ################################  7533  ################################
# Total loss:  -2.3707 | PDE Loss:  -3.4819 | Function Loss:  -3.0168
# ################################  7534  ################################
# Total loss:  -3.013 | PDE Loss:  -4.2895 | Function Loss:  -3.3401
# ################################  7535  ################################
# Total loss:  -2.6031 | PDE Loss:  -3.7452 | Function Loss:  -3.1574
# ################################  7536  ################################
# Total loss:  -2.8645 | PDE Loss:  -4.1415 | Function Loss:  -3.1909
# ################################  7537  ################################
# Total loss:  -2.5229 | PDE Loss:  -3.6596 | Function Loss:  -3.0913
# ################################  7538  ################################
# Total loss:  -2.4033 | PDE Loss:  -3.5967 | Function Loss:  -2.8477
# ################################  7539  ################################
# Total loss:  -2.7717 | PDE Loss:  -4.1512 | Function Loss:  -3.0063
# ################################  7540  ################################
# Total loss:  -2.5692 | PDE Loss:  -3.7112 | Function Loss:  -3.1236
# ################################  7541  ################################
# Total loss:  -2.4241 | PDE Loss:  -3.7353 | Function Loss:  -2.7152
# ################################  7542  ################################
# Total loss:  -2.6559 | PDE Loss:  -4.1107 | Function Loss:  -2.8436
# ################################  7543  ################################
# Total loss:  -2.7572 | PDE Loss:  -3.8997 | Function Loss:  -3.3105
# ################################  7544  ################################
# Total loss:  -2.6395 | PDE Loss:  -4.1 | Function Loss:  -2.8241
# ################################  7545  ################################
# Total loss:  -2.6878 | PDE Loss:  -3.9137 | Function Loss:  -3.0797
# ################################  7546  ################################
# Total loss:  -2.9433 | PDE Loss:  -4.2559 | Function Loss:  -3.233
# ################################  7547  ################################
# Total loss:  -2.6301 | PDE Loss:  -3.8014 | Function Loss:  -3.1169
# ################################  7548  ################################
# Total loss:  -2.9776 | PDE Loss:  -4.1496 | Function Loss:  -3.4629
# ################################  7549  ################################
# Total loss:  -2.4246 | PDE Loss:  -3.5398 | Function Loss:  -3.0572
# ################################  7550  ################################
# Total loss:  -2.2293 | PDE Loss:  -3.3205 | Function Loss:  -2.9516
# ################################  7551  ################################
# Total loss:  -2.4992 | PDE Loss:  -3.6109 | Function Loss:  -3.1435
# ################################  7552  ################################
# Total loss:  -2.9152 | PDE Loss:  -4.0761 | Function Loss:  -3.4245
# ################################  7553  ################################
# Total loss:  -2.7902 | PDE Loss:  -3.8996 | Function Loss:  -3.4425
# ################################  7554  ################################
# Total loss:  -2.8995 | PDE Loss:  -4.0612 | Function Loss:  -3.4068
# ################################  7555  ################################
# Total loss:  -3.1012 | PDE Loss:  -4.2854 | Function Loss:  -3.5626
# ################################  7556  ################################
# Total loss:  -2.533 | PDE Loss:  -3.6602 | Function Loss:  -3.1281
# ################################  7557  ################################
# Total loss:  -2.6405 | PDE Loss:  -3.762 | Function Loss:  -3.2532
# ################################  7558  ################################
# Total loss:  -2.7906 | PDE Loss:  -4.0114 | Function Loss:  -3.19
# ################################  7559  ################################
# Total loss:  -2.7623 | PDE Loss:  -3.9144 | Function Loss:  -3.2917
# ################################  7560  ################################
# Total loss:  -2.9149 | PDE Loss:  -4.0569 | Function Loss:  -3.4696
# ################################  7561  ################################
# Total loss:  -2.8782 | PDE Loss:  -4.0605 | Function Loss:  -3.3433
# ################################  7562  ################################
# Total loss:  -2.7264 | PDE Loss:  -3.9115 | Function Loss:  -3.1861
# ################################  7563  ################################
# Total loss:  -3.0192 | PDE Loss:  -4.2309 | Function Loss:  -3.4328
# ################################  7564  ################################
# Total loss:  -2.3082 | PDE Loss:  -3.4795 | Function Loss:  -2.7951
# ################################  7565  ################################
# Total loss:  -2.1009 | PDE Loss:  -3.2817 | Function Loss:  -2.5689
# ################################  7566  ################################
# Total loss:  -2.4124 | PDE Loss:  -3.563 | Function Loss:  -2.9455
# ################################  7567  ################################
# Total loss:  -2.8018 | PDE Loss:  -3.9668 | Function Loss:  -3.302
# ################################  7568  ################################
# Total loss:  -2.5967 | PDE Loss:  -3.7201 | Function Loss:  -3.2033
# ################################  7569  ################################
# Total loss:  -2.7909 | PDE Loss:  -3.9426 | Function Loss:  -3.3212
# ################################  7570  ################################
# Total loss:  -2.5642 | PDE Loss:  -3.6955 | Function Loss:  -3.1476
# ################################  7571  ################################
# Total loss:  -2.4732 | PDE Loss:  -3.6165 | Function Loss:  -3.0244
# ################################  7572  ################################
# Total loss:  -3.155 | PDE Loss:  -4.3691 | Function Loss:  -3.5648
# ################################  7573  ################################
# Total loss:  -2.5794 | PDE Loss:  -3.6946 | Function Loss:  -3.212
# ################################  7574  ################################
# Total loss:  -2.7842 | PDE Loss:  -3.9586 | Function Loss:  -3.2649
# ################################  7575  ################################
# Total loss:  -2.5928 | PDE Loss:  -3.689 | Function Loss:  -3.2947
# ################################  7576  ################################
# Total loss:  -2.4896 | PDE Loss:  -3.5921 | Function Loss:  -3.1669
# ################################  7577  ################################
# Total loss:  -3.0721 | PDE Loss:  -4.2902 | Function Loss:  -3.4757
# ################################  7578  ################################
# Total loss:  -2.314 | PDE Loss:  -3.4558 | Function Loss:  -2.8691
# ################################  7579  ################################
# Total loss:  -2.0929 | PDE Loss:  -3.2346 | Function Loss:  -2.6485
# ################################  7580  ################################
# Total loss:  -2.2735 | PDE Loss:  -3.4237 | Function Loss:  -2.8077
# ################################  7581  ################################
# Total loss:  -2.9362 | PDE Loss:  -4.1411 | Function Loss:  -3.3611
# ################################  7582  ################################
# Total loss:  -2.265 | PDE Loss:  -3.3902 | Function Loss:  -2.8662
# ################################  7583  ################################
# Total loss:  -2.0019 | PDE Loss:  -3.1092 | Function Loss:  -2.6615
# ################################  7584  ################################
# Total loss:  -2.0708 | PDE Loss:  -3.1674 | Function Loss:  -2.7713
# ################################  7585  ################################
# Total loss:  -2.4289 | PDE Loss:  -3.593 | Function Loss:  -2.9311
# ################################  7586  ################################
# Total loss:  -2.6088 | PDE Loss:  -3.8995 | Function Loss:  -2.9204
# ################################  7587  ################################
# Total loss:  -2.3415 | PDE Loss:  -3.4925 | Function Loss:  -2.8737
# ################################  7588  ################################
# Total loss:  -2.5248 | PDE Loss:  -3.6967 | Function Loss:  -3.0106
# ################################  7589  ################################
# Total loss:  -2.9204 | PDE Loss:  -4.1308 | Function Loss:  -3.3361
# ################################  7590  ################################
# Total loss:  -2.7368 | PDE Loss:  -4.0029 | Function Loss:  -3.0758
# ################################  7591  ################################
# Total loss:  -2.8889 | PDE Loss:  -4.1821 | Function Loss:  -3.1979
# ################################  7592  ################################
# Total loss:  -2.86 | PDE Loss:  -4.1789 | Function Loss:  -3.1438
# ################################  7593  ################################
# Total loss:  -2.8021 | PDE Loss:  -4.0494 | Function Loss:  -3.1645
# ################################  7594  ################################
# Total loss:  -2.9995 | PDE Loss:  -4.2248 | Function Loss:  -3.3924
# ################################  7595  ################################
# Total loss:  -2.8521 | PDE Loss:  -4.0207 | Function Loss:  -3.3446
# ################################  7596  ################################
# Total loss:  -3.0434 | PDE Loss:  -4.2407 | Function Loss:  -3.481
# ################################  7597  ################################
# Total loss:  -2.8247 | PDE Loss:  -4.0094 | Function Loss:  -3.2851
# ################################  7598  ################################
# Total loss:  -2.9698 | PDE Loss:  -4.1828 | Function Loss:  -3.3812
# ################################  7599  ################################
# Total loss:  -2.9927 | PDE Loss:  -4.2231 | Function Loss:  -3.3779
# ################################  7600  ################################
# Total loss:  -2.7815 | PDE Loss:  -3.9602 | Function Loss:  -3.2535
# ################################  7601  ################################
# Total loss:  -3.1415 | PDE Loss:  -4.344 | Function Loss:  -3.5701
# ################################  7602  ################################
# Total loss:  -2.9479 | PDE Loss:  -4.1027 | Function Loss:  -3.4711
# ################################  7603  ################################
# Total loss:  -2.9797 | PDE Loss:  -4.1511 | Function Loss:  -3.4663
# ################################  7604  ################################
# Total loss:  -3.125 | PDE Loss:  -4.3458 | Function Loss:  -3.5246
# ################################  7605  ################################
# Total loss:  -2.8909 | PDE Loss:  -4.0606 | Function Loss:  -3.3812
# ################################  7606  ################################
# Total loss:  -2.7533 | PDE Loss:  -3.9474 | Function Loss:  -3.1965
# ################################  7607  ################################
# Total loss:  -3.1641 | PDE Loss:  -4.3757 | Function Loss:  -3.578
# ################################  7608  ################################
# Total loss:  -2.7288 | PDE Loss:  -3.8912 | Function Loss:  -3.2346
# ################################  7609  ################################
# Total loss:  -3.0084 | PDE Loss:  -4.2607 | Function Loss:  -3.3642
# ################################  7610  ################################
# Total loss:  -3.0453 | PDE Loss:  -4.2395 | Function Loss:  -3.4885
# ################################  7611  ################################
# Total loss:  -2.9216 | PDE Loss:  -4.1139 | Function Loss:  -3.3679
# ################################  7612  ################################
# Total loss:  -3.0832 | PDE Loss:  -4.329 | Function Loss:  -3.4475
# ################################  7613  ################################
# Total loss:  -3.1398 | PDE Loss:  -4.3257 | Function Loss:  -3.5977
# ################################  7614  ################################
# Total loss:  -2.7934 | PDE Loss:  -3.9672 | Function Loss:  -3.2751
# ################################  7615  ################################
# Total loss:  -3.0216 | PDE Loss:  -4.2433 | Function Loss:  -3.4199
# ################################  7616  ################################
# Total loss:  -2.7698 | PDE Loss:  -3.919 | Function Loss:  -3.3063
# ################################  7617  ################################
# Total loss:  -3.125 | PDE Loss:  -4.3722 | Function Loss:  -3.4876
# ################################  7618  ################################
# Total loss:  -2.7697 | PDE Loss:  -3.9952 | Function Loss:  -3.1622
# ################################  7619  ################################
# Total loss:  -3.0495 | PDE Loss:  -4.3314 | Function Loss:  -3.3706
# ################################  7620  ################################
# Total loss:  -2.7022 | PDE Loss:  -4.0285 | Function Loss:  -2.9793
# ################################  7621  ################################
# Total loss:  -2.7845 | PDE Loss:  -4.2563 | Function Loss:  -2.9633
# ################################  7622  ################################
# Total loss:  -2.8551 | PDE Loss:  -4.0973 | Function Loss:  -3.2241
# ################################  7623  ################################
# Total loss:  -2.7603 | PDE Loss:  -4.0628 | Function Loss:  -3.0598
# ################################  7624  ################################
# Total loss:  -3.0903 | PDE Loss:  -4.2714 | Function Loss:  -3.5574
# ################################  7625  ################################
# Total loss:  -2.6303 | PDE Loss:  -3.8329 | Function Loss:  -3.0589
# ################################  7626  ################################
# Total loss:  -2.7832 | PDE Loss:  -3.9925 | Function Loss:  -3.2007
# ################################  7627  ################################
# Total loss:  -2.714 | PDE Loss:  -3.8796 | Function Loss:  -3.2128
# ################################  7628  ################################
# Total loss:  -2.7638 | PDE Loss:  -3.99 | Function Loss:  -3.1553
# ################################  7629  ################################
# Total loss:  -2.7869 | PDE Loss:  -3.9514 | Function Loss:  -3.2881
# ################################  7630  ################################
# Total loss:  -2.751 | PDE Loss:  -4.012 | Function Loss:  -3.0962
# ################################  7631  ################################
# Total loss:  -2.9294 | PDE Loss:  -4.0732 | Function Loss:  -3.4794
# ################################  7632  ################################
# Total loss:  -2.8583 | PDE Loss:  -4.1876 | Function Loss:  -3.1328
# ################################  7633  ################################
# Total loss:  -2.8031 | PDE Loss:  -3.9362 | Function Loss:  -3.3816
# ################################  7634  ################################
# Total loss:  -3.0302 | PDE Loss:  -4.3151 | Function Loss:  -3.3479
# ################################  7635  ################################
# Total loss:  -3.0187 | PDE Loss:  -4.2194 | Function Loss:  -3.4504
# ################################  7636  ################################
# Total loss:  -2.633 | PDE Loss:  -3.7905 | Function Loss:  -3.1498
# ################################  7637  ################################
# Total loss:  -2.8846 | PDE Loss:  -4.065 | Function Loss:  -3.3534
# ################################  7638  ################################
# Total loss:  -2.3933 | PDE Loss:  -3.5038 | Function Loss:  -3.0416
# ################################  7639  ################################
# Total loss:  -2.1985 | PDE Loss:  -3.3005 | Function Loss:  -2.8777
# ################################  7640  ################################
# Total loss:  -2.4922 | PDE Loss:  -3.6016 | Function Loss:  -3.1444
# ################################  7641  ################################
# Total loss:  -2.7123 | PDE Loss:  -3.8873 | Function Loss:  -3.1916
# ################################  7642  ################################
# Total loss:  -2.5677 | PDE Loss:  -3.6873 | Function Loss:  -3.1862
# ################################  7643  ################################
# Total loss:  -2.6743 | PDE Loss:  -3.8757 | Function Loss:  -3.1048
# ################################  7644  ################################
# Total loss:  -2.7537 | PDE Loss:  -3.9001 | Function Loss:  -3.2973
# ################################  7645  ################################
# Total loss:  -2.8077 | PDE Loss:  -4.0161 | Function Loss:  -3.2266
# ################################  7646  ################################
# Total loss:  -2.6276 | PDE Loss:  -3.7833 | Function Loss:  -3.1487
# ################################  7647  ################################
# Total loss:  -2.6386 | PDE Loss:  -3.8059 | Function Loss:  -3.1338
# ################################  7648  ################################
# Total loss:  -2.8696 | PDE Loss:  -4.0399 | Function Loss:  -3.3586
# ################################  7649  ################################
# Total loss:  -2.8605 | PDE Loss:  -3.9792 | Function Loss:  -3.482
# ################################  7650  ################################
# Total loss:  -2.9213 | PDE Loss:  -4.0904 | Function Loss:  -3.4129
# ################################  7651  ################################
# Total loss:  -2.9548 | PDE Loss:  -4.1213 | Function Loss:  -3.4518
# ################################  7652  ################################
# Total loss:  -2.5776 | PDE Loss:  -3.7348 | Function Loss:  -3.095
# ################################  7653  ################################
# Total loss:  -2.7511 | PDE Loss:  -3.9061 | Function Loss:  -3.2736
# ################################  7654  ################################
# Total loss:  -2.4637 | PDE Loss:  -3.6193 | Function Loss:  -2.985
# ################################  7655  ################################
# Total loss:  -2.2731 | PDE Loss:  -3.4138 | Function Loss:  -2.8312
# ################################  7656  ################################
# Total loss:  -2.6853 | PDE Loss:  -3.8245 | Function Loss:  -3.247
# ################################  7657  ################################
# Total loss:  -2.3796 | PDE Loss:  -3.5148 | Function Loss:  -2.9522
# ################################  7658  ################################
# Total loss:  -2.1058 | PDE Loss:  -3.2213 | Function Loss:  -2.7375
# ################################  7659  ################################
# Total loss:  -2.2486 | PDE Loss:  -3.3564 | Function Loss:  -2.9067
# ################################  7660  ################################
# Total loss:  -2.7829 | PDE Loss:  -3.9282 | Function Loss:  -3.329
# ################################  7661  ################################
# Total loss:  -2.3834 | PDE Loss:  -3.485 | Function Loss:  -3.0639
# ################################  7662  ################################
# Total loss:  -2.0706 | PDE Loss:  -3.1526 | Function Loss:  -2.8346
# ################################  7663  ################################
# Total loss:  -2.0805 | PDE Loss:  -3.1721 | Function Loss:  -2.8014
# ################################  7664  ################################
# Total loss:  -2.4142 | PDE Loss:  -3.5434 | Function Loss:  -3.0038
# ################################  7665  ################################
# Total loss:  -2.9502 | PDE Loss:  -4.0805 | Function Loss:  -3.5364
# ################################  7666  ################################
# Total loss:  -2.6769 | PDE Loss:  -3.8264 | Function Loss:  -3.2126
# ################################  7667  ################################
# Total loss:  -3.0855 | PDE Loss:  -4.3095 | Function Loss:  -3.4803
# ################################  7668  ################################
# Total loss:  -2.9545 | PDE Loss:  -4.2362 | Function Loss:  -3.2757
# ################################  7669  ################################
# Total loss:  -2.843 | PDE Loss:  -4.0165 | Function Loss:  -3.3255
# ################################  7670  ################################
# Total loss:  -2.921 | PDE Loss:  -4.2058 | Function Loss:  -3.2389
# ################################  7671  ################################
# Total loss:  -3.0647 | PDE Loss:  -4.2718 | Function Loss:  -3.4857
# ################################  7672  ################################
# Total loss:  -2.8313 | PDE Loss:  -3.9664 | Function Loss:  -3.4041
# ################################  7673  ################################
# Total loss:  -3.165 | PDE Loss:  -4.3575 | Function Loss:  -3.6111
# ################################  7674  ################################
# Total loss:  -2.7426 | PDE Loss:  -3.9371 | Function Loss:  -3.1851
# ################################  7675  ################################
# Total loss:  -3.1333 | PDE Loss:  -4.3531 | Function Loss:  -3.5343
# ################################  7676  ################################
# Total loss:  -2.5375 | PDE Loss:  -3.6924 | Function Loss:  -3.0604
# ################################  7677  ################################
# Total loss:  -2.5836 | PDE Loss:  -3.7675 | Function Loss:  -3.0455
# ################################  7678  ################################
# Total loss:  -2.9777 | PDE Loss:  -4.1835 | Function Loss:  -3.4009
# ################################  7679  ################################
# Total loss:  -2.8205 | PDE Loss:  -4.0531 | Function Loss:  -3.2027
# ################################  7680  ################################
# Total loss:  -2.8967 | PDE Loss:  -4.1156 | Function Loss:  -3.299
# ################################  7681  ################################
# Total loss:  -2.9441 | PDE Loss:  -4.2956 | Function Loss:  -3.1998
# ################################  7682  ################################
# Total loss:  -2.9925 | PDE Loss:  -4.1763 | Function Loss:  -3.4548
# ################################  7683  ################################
# Total loss:  -2.7139 | PDE Loss:  -3.9791 | Function Loss:  -3.054
# ################################  7684  ################################
# Total loss:  -2.9737 | PDE Loss:  -4.1894 | Function Loss:  -3.381
# ################################  7685  ################################
# Total loss:  -2.4929 | PDE Loss:  -3.6935 | Function Loss:  -2.9247
# ################################  7686  ################################
# Total loss:  -2.2723 | PDE Loss:  -3.4943 | Function Loss:  -2.6699
# ################################  7687  ################################
# Total loss:  -2.4355 | PDE Loss:  -3.7223 | Function Loss:  -2.7511
# ################################  7688  ################################
# Total loss:  -2.8685 | PDE Loss:  -4.1408 | Function Loss:  -3.2003
# ################################  7689  ################################
# Total loss:  -2.5051 | PDE Loss:  -3.7659 | Function Loss:  -2.8504
# ################################  7690  ################################
# Total loss:  -2.4037 | PDE Loss:  -3.8075 | Function Loss:  -2.6218
# ################################  7691  ################################
# Total loss:  -2.7216 | PDE Loss:  -4.176 | Function Loss:  -2.9095
# ################################  7692  ################################
# Total loss:  -2.6673 | PDE Loss:  -3.9686 | Function Loss:  -2.968
# ################################  7693  ################################
# Total loss:  -2.5728 | PDE Loss:  -4.0367 | Function Loss:  -2.7557
# ################################  7694  ################################
# Total loss:  -2.7473 | PDE Loss:  -4.0191 | Function Loss:  -3.0796
# ################################  7695  ################################
# Total loss:  -2.7005 | PDE Loss:  -4.1677 | Function Loss:  -2.8816
# ################################  7696  ################################
# Total loss:  -2.6404 | PDE Loss:  -4.0625 | Function Loss:  -2.847
# ################################  7697  ################################
# Total loss:  -3.0349 | PDE Loss:  -4.3151 | Function Loss:  -3.3578
# ################################  7698  ################################
# Total loss:  -2.549 | PDE Loss:  -3.7916 | Function Loss:  -2.9177
# ################################  7699  ################################
# Total loss:  -2.5642 | PDE Loss:  -3.8557 | Function Loss:  -2.8749
# ################################  7700  ################################
# Total loss:  -3.0081 | PDE Loss:  -4.1855 | Function Loss:  -3.4826
# ################################  7701  ################################
# Total loss:  -2.6202 | PDE Loss:  -3.9921 | Function Loss:  -2.8604
# ################################  7702  ################################
# Total loss:  -2.7121 | PDE Loss:  -4.1174 | Function Loss:  -2.9292
# ################################  7703  ################################
# Total loss:  -2.7802 | PDE Loss:  -4.1075 | Function Loss:  -3.0564
# ################################  7704  ################################
# Total loss:  -2.7811 | PDE Loss:  -4.1847 | Function Loss:  -2.9992
# ################################  7705  ################################
# Total loss:  -2.9085 | PDE Loss:  -4.1785 | Function Loss:  -3.243
# ################################  7706  ################################
# Total loss:  -2.5612 | PDE Loss:  -3.7474 | Function Loss:  -3.0189
# ################################  7707  ################################
# Total loss:  -2.6144 | PDE Loss:  -3.8404 | Function Loss:  -3.006
# ################################  7708  ################################
# Total loss:  -2.8402 | PDE Loss:  -4.0036 | Function Loss:  -3.344
# ################################  7709  ################################
# Total loss:  -2.8222 | PDE Loss:  -4.177 | Function Loss:  -3.0754
# ################################  7710  ################################
# Total loss:  -2.9983 | PDE Loss:  -4.209 | Function Loss:  -3.4135
# ################################  7711  ################################
# Total loss:  -2.3945 | PDE Loss:  -3.6849 | Function Loss:  -2.7064
# ################################  7712  ################################
# Total loss:  -2.2534 | PDE Loss:  -3.6023 | Function Loss:  -2.5114
# ################################  7713  ################################
# Total loss:  -2.7017 | PDE Loss:  -4.1257 | Function Loss:  -2.9071
# ################################  7714  ################################
# Total loss:  -2.3933 | PDE Loss:  -3.5794 | Function Loss:  -2.8513
# ################################  7715  ################################
# Total loss:  -2.1566 | PDE Loss:  -3.4944 | Function Loss:  -2.4238
# ################################  7716  ################################
# Total loss:  -2.2679 | PDE Loss:  -3.7713 | Function Loss:  -2.4315
# ################################  7717  ################################
# Total loss:  -2.5151 | PDE Loss:  -3.8192 | Function Loss:  -2.8131
# ################################  7718  ################################
# Total loss:  -2.6151 | PDE Loss:  -3.7576 | Function Loss:  -3.1684
# ################################  7719  ################################
# Total loss:  -2.5425 | PDE Loss:  -3.9509 | Function Loss:  -2.7576
# ################################  7720  ################################
# Total loss:  -2.412 | PDE Loss:  -3.6285 | Function Loss:  -2.8182
# ################################  7721  ################################
# Total loss:  -2.893 | PDE Loss:  -4.0307 | Function Loss:  -3.4586
# ################################  7722  ################################
# Total loss:  -2.1973 | PDE Loss:  -3.4078 | Function Loss:  -2.6129
# ################################  7723  ################################
# Total loss:  -1.8436 | PDE Loss:  -3.0344 | Function Loss:  -2.2926
# ################################  7724  ################################
# Total loss:  -1.8006 | PDE Loss:  -2.9969 | Function Loss:  -2.2399
# ################################  7725  ################################
# Total loss:  -1.9568 | PDE Loss:  -3.1851 | Function Loss:  -2.3453
# ################################  7726  ################################
# Total loss:  -2.3547 | PDE Loss:  -3.7231 | Function Loss:  -2.5975
# ################################  7727  ################################
# Total loss:  -2.5116 | PDE Loss:  -3.7933 | Function Loss:  -2.8329
# ################################  7728  ################################
# Total loss:  -2.408 | PDE Loss:  -3.6757 | Function Loss:  -2.7451
# ################################  7729  ################################
# Total loss:  -2.3592 | PDE Loss:  -3.8707 | Function Loss:  -2.5191
# ################################  7730  ################################
# Total loss:  -2.3466 | PDE Loss:  -3.7705 | Function Loss:  -2.552
# ################################  7731  ################################
# Total loss:  -2.7272 | PDE Loss:  -4.0326 | Function Loss:  -3.0239
# ################################  7732  ################################
# Total loss:  -2.3312 | PDE Loss:  -3.6344 | Function Loss:  -2.6299
# ################################  7733  ################################
# Total loss:  -2.028 | PDE Loss:  -3.3599 | Function Loss:  -2.3002
# ################################  7734  ################################
# Total loss:  -2.0859 | PDE Loss:  -3.4718 | Function Loss:  -2.3159
# ################################  7735  ################################
# Total loss:  -2.502 | PDE Loss:  -3.9969 | Function Loss:  -2.6694
# ################################  7736  ################################
# Total loss:  -2.4841 | PDE Loss:  -3.6373 | Function Loss:  -3.0111
# ################################  7737  ################################
# Total loss:  -2.3122 | PDE Loss:  -3.6176 | Function Loss:  -2.6089
# ################################  7738  ################################
# Total loss:  -2.5078 | PDE Loss:  -3.9772 | Function Loss:  -2.6878
# ################################  7739  ################################
# Total loss:  -2.5548 | PDE Loss:  -3.6839 | Function Loss:  -3.1447
# ################################  7740  ################################
# Total loss:  -2.6574 | PDE Loss:  -3.9833 | Function Loss:  -2.9349
# ################################  7741  ################################
# Total loss:  -2.4787 | PDE Loss:  -3.7453 | Function Loss:  -2.8171
# ################################  7742  ################################
# Total loss:  -2.541 | PDE Loss:  -3.6873 | Function Loss:  -3.0845
# ################################  7743  ################################
# Total loss:  -2.871 | PDE Loss:  -4.2035 | Function Loss:  -3.1426
# ################################  7744  ################################
# Total loss:  -2.9261 | PDE Loss:  -4.1576 | Function Loss:  -3.3099
# ################################  7745  ################################
# Total loss:  -2.5217 | PDE Loss:  -3.7637 | Function Loss:  -2.8911
# ################################  7746  ################################
# Total loss:  -2.496 | PDE Loss:  -3.8592 | Function Loss:  -2.7426
# ################################  7747  ################################
# Total loss:  -2.772 | PDE Loss:  -4.0624 | Function Loss:  -3.0839
# ################################  7748  ################################
# Total loss:  -2.837 | PDE Loss:  -4.0407 | Function Loss:  -3.2637
# ################################  7749  ################################
# Total loss:  -2.5578 | PDE Loss:  -3.7843 | Function Loss:  -2.9487
# ################################  7750  ################################
# Total loss:  -2.7015 | PDE Loss:  -3.8488 | Function Loss:  -3.2425
# ################################  7751  ################################
# Total loss:  -2.5341 | PDE Loss:  -3.8411 | Function Loss:  -2.8292
# ################################  7752  ################################
# Total loss:  -2.4641 | PDE Loss:  -3.7028 | Function Loss:  -2.838
# ################################  7753  ################################
# Total loss:  -3.0724 | PDE Loss:  -4.3905 | Function Loss:  -3.357
# ################################  7754  ################################
# Total loss:  -2.6453 | PDE Loss:  -3.9661 | Function Loss:  -2.9274
# ################################  7755  ################################
# Total loss:  -2.8279 | PDE Loss:  -4.2293 | Function Loss:  -3.0474
# ################################  7756  ################################
# Total loss:  -2.7855 | PDE Loss:  -4.127 | Function Loss:  -3.0494
# ################################  7757  ################################
# Total loss:  -2.7146 | PDE Loss:  -4.0286 | Function Loss:  -3.0031
# ################################  7758  ################################
# Total loss:  -3.0353 | PDE Loss:  -4.2763 | Function Loss:  -3.4061
# ################################  7759  ################################
# Total loss:  -2.33 | PDE Loss:  -3.5001 | Function Loss:  -2.8193
# ################################  7760  ################################
# Total loss:  -2.1347 | PDE Loss:  -3.3261 | Function Loss:  -2.5827
# ################################  7761  ################################
# Total loss:  -2.3959 | PDE Loss:  -3.6348 | Function Loss:  -2.7694
# ################################  7762  ################################
# Total loss:  -2.8355 | PDE Loss:  -4.0419 | Function Loss:  -3.2578
# ################################  7763  ################################
# Total loss:  -2.7172 | PDE Loss:  -4.0113 | Function Loss:  -3.0253
# ################################  7764  ################################
# Total loss:  -2.6774 | PDE Loss:  -3.9885 | Function Loss:  -2.9685
# ################################  7765  ################################
# Total loss:  -3.0291 | PDE Loss:  -4.2142 | Function Loss:  -3.4886
# ################################  7766  ################################
# Total loss:  -2.4924 | PDE Loss:  -3.705 | Function Loss:  -2.9046
# ################################  7767  ################################
# Total loss:  -2.6447 | PDE Loss:  -3.8063 | Function Loss:  -3.1522
# ################################  7768  ################################
# Total loss:  -2.6029 | PDE Loss:  -3.8656 | Function Loss:  -2.946
# ################################  7769  ################################
# Total loss:  -2.5488 | PDE Loss:  -3.7843 | Function Loss:  -2.9269
# ################################  7770  ################################
# Total loss:  -2.9274 | PDE Loss:  -4.1375 | Function Loss:  -3.3436
# ################################  7771  ################################
# Total loss:  -2.8011 | PDE Loss:  -4.0021 | Function Loss:  -3.2322
# ################################  7772  ################################
# Total loss:  -2.9324 | PDE Loss:  -4.1068 | Function Loss:  -3.4131
# ################################  7773  ################################
# Total loss:  -2.6312 | PDE Loss:  -3.8141 | Function Loss:  -3.095
# ################################  7774  ################################
# Total loss:  -2.6961 | PDE Loss:  -3.9269 | Function Loss:  -3.0811
# ################################  7775  ################################
# Total loss:  -2.7493 | PDE Loss:  -3.9473 | Function Loss:  -3.1856
# ################################  7776  ################################
# Total loss:  -2.872 | PDE Loss:  -4.1263 | Function Loss:  -3.2254
# ################################  7777  ################################
# Total loss:  -2.6028 | PDE Loss:  -3.8085 | Function Loss:  -3.0261
# ################################  7778  ################################
# Total loss:  -2.6817 | PDE Loss:  -3.8927 | Function Loss:  -3.0965
# ################################  7779  ################################
# Total loss:  -2.7008 | PDE Loss:  -3.94 | Function Loss:  -3.074
# ################################  7780  ################################
# Total loss:  -2.7828 | PDE Loss:  -3.9293 | Function Loss:  -3.3258
# ################################  7781  ################################
# Total loss:  -2.6601 | PDE Loss:  -3.8942 | Function Loss:  -3.0402
# ################################  7782  ################################
# Total loss:  -2.7671 | PDE Loss:  -3.9173 | Function Loss:  -3.3014
# ################################  7783  ################################
# Total loss:  -2.7206 | PDE Loss:  -3.9381 | Function Loss:  -3.1253
# ################################  7784  ################################
# Total loss:  -2.7573 | PDE Loss:  -3.9053 | Function Loss:  -3.2966
# ################################  7785  ################################
# Total loss:  -2.8322 | PDE Loss:  -4.0796 | Function Loss:  -3.1946
# ################################  7786  ################################
# Total loss:  -2.6371 | PDE Loss:  -3.7791 | Function Loss:  -3.1916
# ################################  7787  ################################
# Total loss:  -2.8458 | PDE Loss:  -4.0455 | Function Loss:  -3.2792
# ################################  7788  ################################
# Total loss:  -2.3593 | PDE Loss:  -3.4823 | Function Loss:  -2.9671
# ################################  7789  ################################
# Total loss:  -2.1052 | PDE Loss:  -3.2322 | Function Loss:  -2.7013
# ################################  7790  ################################
# Total loss:  -2.3493 | PDE Loss:  -3.4829 | Function Loss:  -2.9265
# ################################  7791  ################################
# Total loss:  -3.0044 | PDE Loss:  -4.2309 | Function Loss:  -3.3953
# ################################  7792  ################################
# Total loss:  -2.7452 | PDE Loss:  -3.9396 | Function Loss:  -3.1879
# ################################  7793  ################################
# Total loss:  -2.8943 | PDE Loss:  -4.1891 | Function Loss:  -3.2016
# ################################  7794  ################################
# Total loss:  -2.6691 | PDE Loss:  -3.8946 | Function Loss:  -3.0616
# ################################  7795  ################################
# Total loss:  -2.7102 | PDE Loss:  -4.0688 | Function Loss:  -2.9603
# ################################  7796  ################################
# Total loss:  -2.823 | PDE Loss:  -4.0027 | Function Loss:  -3.293
# ################################  7797  ################################
# Total loss:  -2.8661 | PDE Loss:  -4.1927 | Function Loss:  -3.143
# ################################  7798  ################################
# Total loss:  -2.8661 | PDE Loss:  -4.016 | Function Loss:  -3.4006
# ################################  7799  ################################
# Total loss:  -2.7784 | PDE Loss:  -4.0482 | Function Loss:  -3.1131
# ################################  7800  ################################
# Total loss:  -2.9188 | PDE Loss:  -4.1095 | Function Loss:  -3.3683
# ################################  7801  ################################
# Total loss:  -2.7082 | PDE Loss:  -3.9388 | Function Loss:  -3.0933
# ################################  7802  ################################
# Total loss:  -2.8058 | PDE Loss:  -4.0594 | Function Loss:  -3.16
# ################################  7803  ################################
# Total loss:  -2.7826 | PDE Loss:  -3.9838 | Function Loss:  -3.2134
# ################################  7804  ################################
# Total loss:  -2.7183 | PDE Loss:  -4.0206 | Function Loss:  -3.018
# ################################  7805  ################################
# Total loss:  -3.0249 | PDE Loss:  -4.1846 | Function Loss:  -3.5368
# ################################  7806  ################################
# Total loss:  -2.5496 | PDE Loss:  -3.8744 | Function Loss:  -2.8282
# ################################  7807  ################################
# Total loss:  -2.6163 | PDE Loss:  -3.9845 | Function Loss:  -2.8591
# ################################  7808  ################################
# Total loss:  -2.8158 | PDE Loss:  -3.9832 | Function Loss:  -3.3108
# ################################  7809  ################################
# Total loss:  -2.7898 | PDE Loss:  -4.1401 | Function Loss:  -3.0466
# ################################  7810  ################################
# Total loss:  -2.847 | PDE Loss:  -4.0383 | Function Loss:  -3.2953
# ################################  7811  ################################
# Total loss:  -2.6695 | PDE Loss:  -3.885 | Function Loss:  -3.0771
# ################################  7812  ################################
# Total loss:  -2.7025 | PDE Loss:  -3.9701 | Function Loss:  -3.0397
# ################################  7813  ################################
# Total loss:  -2.8118 | PDE Loss:  -3.9498 | Function Loss:  -3.3771
# ################################  7814  ################################
# Total loss:  -2.875 | PDE Loss:  -4.2368 | Function Loss:  -3.1228
# ################################  7815  ################################
# Total loss:  -2.8864 | PDE Loss:  -4.0398 | Function Loss:  -3.4128
# ################################  7816  ################################
# Total loss:  -2.6835 | PDE Loss:  -3.9971 | Function Loss:  -2.9724
# ################################  7817  ################################
# Total loss:  -2.929 | PDE Loss:  -4.169 | Function Loss:  -3.301
# ################################  7818  ################################
# Total loss:  -2.3734 | PDE Loss:  -3.6154 | Function Loss:  -2.7427
# ################################  7819  ################################
# Total loss:  -2.1288 | PDE Loss:  -3.4145 | Function Loss:  -2.4458
# ################################  7820  ################################
# Total loss:  -2.2813 | PDE Loss:  -3.6256 | Function Loss:  -2.5429
# ################################  7821  ################################
# Total loss:  -2.7723 | PDE Loss:  -4.0624 | Function Loss:  -3.0845
# ################################  7822  ################################
# Total loss:  -2.5064 | PDE Loss:  -3.7614 | Function Loss:  -2.8588
# ################################  7823  ################################
# Total loss:  -2.3073 | PDE Loss:  -3.7264 | Function Loss:  -2.5156
# ################################  7824  ################################
# Total loss:  -2.4289 | PDE Loss:  -3.7842 | Function Loss:  -2.6817
# ################################  7825  ################################
# Total loss:  -2.8075 | PDE Loss:  -3.9541 | Function Loss:  -3.3505
# ################################  7826  ################################
# Total loss:  -2.4393 | PDE Loss:  -3.7295 | Function Loss:  -2.7515
# ################################  7827  ################################
# Total loss:  -2.1835 | PDE Loss:  -3.4702 | Function Loss:  -2.4994
# ################################  7828  ################################
# Total loss:  -2.3408 | PDE Loss:  -3.657 | Function Loss:  -2.6273
# ################################  7829  ################################
# Total loss:  -2.8898 | PDE Loss:  -4.1786 | Function Loss:  -3.2034
# ################################  7830  ################################
# Total loss:  -2.4674 | PDE Loss:  -3.8759 | Function Loss:  -2.6823
# ################################  7831  ################################
# Total loss:  -2.1667 | PDE Loss:  -3.6578 | Function Loss:  -2.3359
# ################################  7832  ################################
# Total loss:  -2.2093 | PDE Loss:  -3.7141 | Function Loss:  -2.3721
# ################################  7833  ################################
# Total loss:  -2.642 | PDE Loss:  -4.0823 | Function Loss:  -2.8377
# ################################  7834  ################################
# Total loss:  -2.6646 | PDE Loss:  -4.0675 | Function Loss:  -2.8831
# ################################  7835  ################################
# Total loss:  -2.3733 | PDE Loss:  -3.8924 | Function Loss:  -2.5298
# ################################  7836  ################################
# Total loss:  -2.564 | PDE Loss:  -4.0281 | Function Loss:  -2.7468
# ################################  7837  ################################
# Total loss:  -2.9862 | PDE Loss:  -4.2107 | Function Loss:  -3.3801
# ################################  7838  ################################
# Total loss:  -2.5561 | PDE Loss:  -3.8421 | Function Loss:  -2.8727
# ################################  7839  ################################
# Total loss:  -2.6286 | PDE Loss:  -3.8485 | Function Loss:  -3.0294
# ################################  7840  ################################
# Total loss:  -2.8659 | PDE Loss:  -4.2421 | Function Loss:  -3.1029
# ...
# Total loss:  -2.8629 | PDE Loss:  -4.3517 | Function Loss:  -3.0333
# ################################  9887  ################################
# Total loss:  -2.8946 | PDE Loss:  -4.1435 | Function Loss:  -3.2549
# ################################  9888  ################################
# Total loss:  -2.8559 | PDE Loss:  -4.2639 | Function Loss:  -3.0711
# ################################  9889  ################################
# Total loss:  -3.0988 | PDE Loss:  -4.43 | Function Loss:  -3.3717
# ################################  9890  ################################
# Total loss:  -2.8308 | PDE Loss:  -4.1458 | Function Loss:  -3.1184
# ################################  9891  ################################
# Total loss:  -3.1229 | PDE Loss:  -4.3443 | Function Loss:  -3.5214
# ################################  9892  ################################
# Total loss:  -3.048 | PDE Loss:  -4.2716 | Function Loss:  -3.4433
# ################################  9893  ################################
# Total loss:  -3.0101 | PDE Loss:  -4.2794 | Function Loss:  -3.3454
# ################################  9894  ################################
# Total loss:  -3.037 | PDE Loss:  -4.2676 | Function Loss:  -3.4222
# ################################  9895  ################################
# Total loss:  -2.919 | PDE Loss:  -4.1351 | Function Loss:  -3.3256
# ################################  9896  ################################
# Total loss:  -3.1502 | PDE Loss:  -4.4527 | Function Loss:  -3.4498
# ################################  9897  ################################
# Total loss:  -3.0519 | PDE Loss:  -4.3476 | Function Loss:  -3.3583
# ################################  9898  ################################
# Total loss:  -3.1925 | PDE Loss:  -4.393 | Function Loss:  -3.6246
# ################################  9899  ################################
# Total loss:  -2.9293 | PDE Loss:  -4.144 | Function Loss:  -3.3382
# ################################  9900  ################################
# Total loss:  -2.9934 | PDE Loss:  -4.3453 | Function Loss:  -3.2489
# ################################  9901  ################################
# Total loss:  -3.1232 | PDE Loss:  -4.2864 | Function Loss:  -3.6274
# ################################  9902  ################################
# Total loss:  -2.9921 | PDE Loss:  -4.1567 | Function Loss:  -3.4933
# ################################  9903  ################################
# Total loss:  -2.9811 | PDE Loss:  -4.3414 | Function Loss:  -3.23
# ################################  9904  ################################
# Total loss:  -3.1115 | PDE Loss:  -4.3545 | Function Loss:  -3.4795
# ################################  9905  ################################
# Total loss:  -3.0212 | PDE Loss:  -4.1819 | Function Loss:  -3.5307
# ################################  9906  ################################
# Total loss:  -2.9255 | PDE Loss:  -4.239 | Function Loss:  -3.2144
# ################################  9907  ################################
# Total loss:  -3.2352 | PDE Loss:  -4.4199 | Function Loss:  -3.6954
# ################################  9908  ################################
# Total loss:  -2.9652 | PDE Loss:  -4.1166 | Function Loss:  -3.4963
# ################################  9909  ################################
# Total loss:  -2.9495 | PDE Loss:  -4.2338 | Function Loss:  -3.268
# ################################  9910  ################################
# Total loss:  -3.2579 | PDE Loss:  -4.4575 | Function Loss:  -3.6915
# ################################  9911  ################################
# Total loss:  -2.9548 | PDE Loss:  -4.0834 | Function Loss:  -3.5463
# ################################  9912  ################################
# Total loss:  -3.0325 | PDE Loss:  -4.2922 | Function Loss:  -3.3791
# ################################  9913  ################################
# Total loss:  -3.0861 | PDE Loss:  -4.2764 | Function Loss:  -3.536
# ################################  9914  ################################
# Total loss:  -2.8327 | PDE Loss:  -4.0131 | Function Loss:  -3.3013
# ################################  9915  ################################
# Total loss:  -3.2475 | PDE Loss:  -4.5171 | Function Loss:  -3.5825
# ################################  9916  ################################
# Total loss:  -2.7241 | PDE Loss:  -3.8963 | Function Loss:  -3.2091
# ################################  9917  ################################
# Total loss:  -3.04 | PDE Loss:  -4.3723 | Function Loss:  -3.3117
# ################################  9918  ################################
# Total loss:  -2.5514 | PDE Loss:  -3.7496 | Function Loss:  -2.9874
# ################################  9919  ################################
# Total loss:  -2.5633 | PDE Loss:  -3.7299 | Function Loss:  -3.0599
# ################################  9920  ################################
# Total loss:  -3.0337 | PDE Loss:  -4.3615 | Function Loss:  -3.3095
# ################################  9921  ################################
# Total loss:  -2.5988 | PDE Loss:  -3.7208 | Function Loss:  -3.2097
# ################################  9922  ################################
# Total loss:  -2.6323 | PDE Loss:  -3.7837 | Function Loss:  -3.1634
# ################################  9923  ################################
# Total loss:  -3.1308 | PDE Loss:  -4.3167 | Function Loss:  -3.5891
# ################################  9924  ################################
# Total loss:  -3.1031 | PDE Loss:  -4.3741 | Function Loss:  -3.4365
# ################################  9925  ################################
# Total loss:  -2.8074 | PDE Loss:  -3.9528 | Function Loss:  -3.3534
# ################################  9926  ################################
# Total loss:  -3.0094 | PDE Loss:  -4.3781 | Function Loss:  -3.2518
# ################################  9927  ################################
# Total loss:  -2.7854 | PDE Loss:  -3.9876 | Function Loss:  -3.2146
# ################################  9928  ################################
# Total loss:  -2.8852 | PDE Loss:  -4.2995 | Function Loss:  -3.0964
# ################################  9929  ################################
# Total loss:  -2.8598 | PDE Loss:  -4.0509 | Function Loss:  -3.3084
# ################################  9930  ################################
# Total loss:  -2.8823 | PDE Loss:  -4.3105 | Function Loss:  -3.0851
# ################################  9931  ################################
# Total loss:  -2.9541 | PDE Loss:  -4.0903 | Function Loss:  -3.5242
# ################################  9932  ################################
# Total loss:  -2.9027 | PDE Loss:  -4.1803 | Function Loss:  -3.2284
# ################################  9933  ################################
# Total loss:  -3.0396 | PDE Loss:  -4.207 | Function Loss:  -3.5346
# ################################  9934  ################################
# Total loss:  -2.6717 | PDE Loss:  -3.8111 | Function Loss:  -3.233
# ################################  9935  ################################
# Total loss:  -2.6305 | PDE Loss:  -3.7781 | Function Loss:  -3.1709
# ################################  9936  ################################
# Total loss:  -3.2374 | PDE Loss:  -4.4562 | Function Loss:  -3.6399
# ################################  9937  ################################
# Total loss:  -2.7808 | PDE Loss:  -3.9907 | Function Loss:  -3.1974
# ################################  9938  ################################
# Total loss:  -3.083 | PDE Loss:  -4.4892 | Function Loss:  -3.2994
# ################################  9939  ################################
# Total loss:  -2.7256 | PDE Loss:  -4.0305 | Function Loss:  -3.0227
# ################################  9940  ################################
# Total loss:  -2.7477 | PDE Loss:  -4.1825 | Function Loss:  -2.9466
# ################################  9941  ################################
# Total loss:  -3.026 | PDE Loss:  -4.2959 | Function Loss:  -3.3607
# ################################  9942  ################################
# Total loss:  -2.6233 | PDE Loss:  -3.8705 | Function Loss:  -2.9858
# ################################  9943  ################################
# Total loss:  -2.6602 | PDE Loss:  -3.9464 | Function Loss:  -2.9767
# ################################  9944  ################################
# Total loss:  -3.0378 | PDE Loss:  -4.2067 | Function Loss:  -3.5296
# ################################  9945  ################################
# Total loss:  -2.836 | PDE Loss:  -4.2238 | Function Loss:  -3.0647
# ################################  9946  ################################
# Total loss:  -3.2041 | PDE Loss:  -4.4305 | Function Loss:  -3.5952
# ################################  9947  ################################
# Total loss:  -2.3408 | PDE Loss:  -3.6874 | Function Loss:  -2.6006
# ################################  9948  ################################
# Total loss:  -2.0704 | PDE Loss:  -3.4598 | Function Loss:  -2.2981
# ################################  9949  ################################
# Total loss:  -2.1453 | PDE Loss:  -3.5982 | Function Loss:  -2.3341
# ################################  9950  ################################
# Total loss:  -2.5451 | PDE Loss:  -4.0618 | Function Loss:  -2.7027
# ################################  9951  ################################
# Total loss:  -2.7173 | PDE Loss:  -3.9278 | Function Loss:  -3.1327
# ################################  9952  ################################
# Total loss:  -2.5646 | PDE Loss:  -4.101 | Function Loss:  -2.7139
# ################################  9953  ################################
# Total loss:  -2.4834 | PDE Loss:  -3.8287 | Function Loss:  -2.7442
# ################################  9954  ################################
# Total loss:  -2.7242 | PDE Loss:  -3.9127 | Function Loss:  -3.1777
# ################################  9955  ################################
# Total loss:  -2.736 | PDE Loss:  -4.0175 | Function Loss:  -3.0574
# ################################  9956  ################################
# Total loss:  -2.5821 | PDE Loss:  -3.848 | Function Loss:  -2.9214
# ################################  9957  ################################
# Total loss:  -3.1141 | PDE Loss:  -4.3153 | Function Loss:  -3.5449
# ################################  9958  ################################
# Total loss:  -2.4992 | PDE Loss:  -3.779 | Function Loss:  -2.8226
# ################################  9959  ################################
# Total loss:  -2.2191 | PDE Loss:  -3.5234 | Function Loss:  -2.5169
# ################################  9960  ################################
# Total loss:  -2.2925 | PDE Loss:  -3.6323 | Function Loss:  -2.558
# ################################  9961  ################################
# Total loss:  -2.7638 | PDE Loss:  -4.1503 | Function Loss:  -2.9935
# ################################  9962  ################################
# Total loss:  -2.6591 | PDE Loss:  -3.9287 | Function Loss:  -2.9941
# ################################  9963  ################################
# Total loss:  -2.3294 | PDE Loss:  -3.7303 | Function Loss:  -2.5493
# ################################  9964  ################################
# Total loss:  -2.451 | PDE Loss:  -3.934 | Function Loss:  -2.6241
# ################################  9965  ################################
# Total loss:  -3.0373 | PDE Loss:  -4.3555 | Function Loss:  -3.3218
# ################################  9966  ################################
# Total loss:  -2.4239 | PDE Loss:  -3.9551 | Function Loss:  -2.5753
# ################################  9967  ################################
# Total loss:  -2.0443 | PDE Loss:  -3.6036 | Function Loss:  -2.1844
# ################################  9968  ################################
# Total loss:  -1.9667 | PDE Loss:  -3.5296 | Function Loss:  -2.1055
# ################################  9969  ################################
# Total loss:  -2.0767 | PDE Loss:  -3.6368 | Function Loss:  -2.2166
# ################################  9970  ################################
# Total loss:  -2.4671 | PDE Loss:  -3.9909 | Function Loss:  -2.6217
# ################################  9971  ################################
# Total loss:  -3.1635 | PDE Loss:  -4.4066 | Function Loss:  -3.5314
# ################################  9972  ################################
# Total loss:  -2.7138 | PDE Loss:  -4.0668 | Function Loss:  -2.9684
# ################################  9973  ################################
# Total loss:  -2.9827 | PDE Loss:  -4.2151 | Function Loss:  -3.3653
# ################################  9974  ################################
# Total loss:  -2.6389 | PDE Loss:  -3.918 | Function Loss:  -2.963
# ################################  9975  ################################
# Total loss:  -2.4276 | PDE Loss:  -3.7207 | Function Loss:  -2.7366
# ################################  9976  ################################
# Total loss:  -2.703 | PDE Loss:  -4.063 | Function Loss:  -2.9521
# ################################  9977  ################################
# Total loss:  -2.9473 | PDE Loss:  -4.1585 | Function Loss:  -3.3617
# ################################  9978  ################################
# Total loss:  -2.7624 | PDE Loss:  -4.0891 | Function Loss:  -3.0392
# ################################  9979  ################################
# Total loss:  -3.0819 | PDE Loss:  -4.3502 | Function Loss:  -3.4184
# ################################  9980  ################################
# Total loss:  -2.5516 | PDE Loss:  -3.8437 | Function Loss:  -2.8619
# ################################  9981  ################################
# Total loss:  -2.3927 | PDE Loss:  -3.758 | Function Loss:  -2.6378
# ################################  9982  ################################
# Total loss:  -2.7221 | PDE Loss:  -4.1505 | Function Loss:  -2.9247
# ################################  9983  ################################
# Total loss:  -2.7972 | PDE Loss:  -3.9899 | Function Loss:  -3.2429
# ################################  9984  ################################
# Total loss:  -2.6273 | PDE Loss:  -4.1146 | Function Loss:  -2.7984
# ################################  9985  ################################
# Total loss:  -2.8666 | PDE Loss:  -4.144 | Function Loss:  -3.1926
# ################################  9986  ################################
# Total loss:  -2.6965 | PDE Loss:  -4.1084 | Function Loss:  -2.9093
# ################################  9987  ################################
# Total loss:  -2.5643 | PDE Loss:  -4.0574 | Function Loss:  -2.7326
# ################################  9988  ################################
# Total loss:  -2.9428 | PDE Loss:  -4.2023 | Function Loss:  -3.2899
# ################################  9989  ################################
# Total loss:  -2.6946 | PDE Loss:  -4.1239 | Function Loss:  -2.8967
# ################################  9990  ################################
# Total loss:  -2.4798 | PDE Loss:  -3.8594 | Function Loss:  -2.7143
# ################################  9991  ################################
# Total loss:  -2.7825 | PDE Loss:  -4.0422 | Function Loss:  -3.1292
# ################################  9992  ################################
# Total loss:  -2.8601 | PDE Loss:  -4.1788 | Function Loss:  -3.1442
# ################################  9993  ################################
# Total loss:  -2.7063 | PDE Loss:  -4.0595 | Function Loss:  -2.9609
# ################################  9994  ################################
# Total loss:  -3.2729 | PDE Loss:  -4.5273 | Function Loss:  -3.6263
# ################################  9995  ################################
# Total loss:  -2.5435 | PDE Loss:  -4.0251 | Function Loss:  -2.7174
# ################################  9996  ################################
# Total loss:  -2.4035 | PDE Loss:  -3.9447 | Function Loss:  -2.5508
# ################################  9997  ################################
# Total loss:  -2.753 | PDE Loss:  -4.1731 | Function Loss:  -2.9606
# ################################  9998  ################################
# Total loss:  -2.831 | PDE Loss:  -4.2031 | Function Loss:  -3.071
# ################################  9999  ################################
# Total loss:  -2.6277 | PDE Loss:  -4.0419 | Function Loss:  -2.8389
# Final Loss:  -2.627655267715454

# %%
pinn.plot()
# Out:
# L2 Relative Error Norm:  2.416720151901245 %
