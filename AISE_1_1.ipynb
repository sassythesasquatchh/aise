# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import time
import torch.nn as nn
torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)

# %% [markdown]
# # Basic theory and problem setup
# Consider the one-dimensional heat equation:
#
# $$
# u_t(t, x) = u_{xx}(t, x), \quad t\in[0,T], ~x\in [-1,1]
# $$
#
#
# with zero Dirichlet boundary conditions
#
# $$
# u_b(t, -1)=u_b(t,1)=0,
# $$
#
# and initial condition
#
# $$
# u(x, 0) = u_0(x) = - \sin(\pi x)
# $$
#
# We want to obtain an approximate solution of the heat equation $u : [0,T]\times[-1,1] \mapsto \mathbb{R}$ with physics informed neural networks (PINNs).
#
# To do so, we approximate the underlying solution with a feedforward dense neural network with tunable parameters $\theta$:
#
# $$
# u_\theta(t,x) \approx u(t,x)
# $$
# Define the following residuals:
#
#    - Interior residual given by,
#
#    $$r_{int,\theta}(t, x):=  u_{\theta, t}(x,t) - u_{\theta, xx}(x,t), \quad \forall ~t \in [0,T],~ x \in [-1,1].$$
#
#
#
#
#    - Spatial boundary residual given by,
#
#         $$r_{sb,\theta}(t,-1):= u_{\theta}(t,-1)- u_b(t,-1), \quad r_{sb,\theta}(t,1):= u_{\theta}(t,1)- u_b(t,1), \quad \forall t \in (0,T].$$
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x):= u_{\theta}(x,0) - u_0(x), \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int}(\theta) = \int_{[0,T]\times[-1,1]}r_{int,\theta}^2(t, x) dtdx, \quad
# L_{sb}(\theta) = \int_{[0,T]}r_{sb,\theta}^2(t,-1) dt + \int_{[0,T]}r_{sb,\theta}^2(t,1)dt, \quad
# L_{tb}(\theta) = \int_{[-1,1]}r_{tb,\theta}^2(x) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t)_n \in D_T,
# $$
#
# $$
# S_{sb, -1} =\{t_n, u_b(t_n,-1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{sb, 1} =\{t_n, u_b(t_n,1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{tb}=\{x_n, u_0(x_n)\}\quad  1 \leq n \leq N_{tb}, x_n \in [-1,1].
# $$
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences.
#
# $$
# L_{int}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta}^2(y_n), \quad
# L_{sb}(\theta) = \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,-1) + \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,1), \quad
# L_{tb}(\theta) = \frac{1}{N_{tb}}\sum_{i=1}^{N_{tb}}r_{tb,\theta}^2(x_n)
# $$
#
# and solve the following minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_u(\theta) = L_{tb}(\theta) + L_{sb}(\theta)
# $$

# %% [markdown]
# # Your task: Solve the $1D$ heat equation using PINNs
#
# You will have to implement the following
#
# *  `NNAnsatz` a neural net approximator for the solution of the heat equation.
# *   Missing functionality in the `PINNTrainer`, namely:
#     *   `PINNTrainer.compute_pde_residual` to compute the PDE loss on your predictions.
#     *   `PINNTrainer.compute_loss` to aggregate all the residuals into a single weighted loss.
#
# Use `torch.autograd.grad` to compute gradients, second derivatives -- some basic examples can be found [here](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html). Make sure the gradients you compute are attached to the computational graph so that you can backpropagate through them.
#
#
# Follow the `TODOs`.

# %%
class NNAnsatz(torch.nn.Module):
  def __init__(self,
               input_dimension,
               output_dimension,
               n_hidden_layers,
               hidden_size):


    super(NNAnsatz, self).__init__()

    self.input_layer=nn.Linear(input_dimension, hidden_size)

    self.hidden_layers = nn.ModuleList()
    for _ in range(n_hidden_layers):
      self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))

    self.output_layer=nn.Linear(hidden_size, output_dimension)

    self.activation = nn.Tanh()


  def forward(self, x):
    # TODO: Do a forward pass on `x`.
    x=self.activation(self.input_layer(x))

    for hidden_layer in self.hidden_layers:
      x = self.activation(hidden_layer(x))

    x=self.activation(self.output_layer(x))

    return x

# %%
class PINNTrainer:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_

        # Extrema of the solution domain (t, x) in [0,0.1] x [-1,1]
        self.domain_extrema = torch.tensor([[0, 1.],  # Time dimension
                                            [0., 1.]])  # Space dimension

        # Number of space dimensions
        self.space_dimensions = 1

        # Parameter to balance role of data and PDE
        self.lambda_u = 10

        # F Dense NN to approximate the solution of the underlying heat equation
        # TODO: Write the `NNAnsatz` class to be a feed-forward neural net
        # that you'll train to approximate your solution.
        self.approximate_solution = NNAnsatz(input_dimension=self.domain_extrema.shape[0],
                                             output_dimension=2,
                                             n_hidden_layers=4,
                                             hidden_size=20)

        # TODO: Setup optimizer.
        self.optimizer = torch.optim.Adam(self.approximate_solution.parameters(),
                                          lr=float(0.001))

        # Generator of Sobol sequences.
        self.soboleng = torch.quasirandom.SobolEngine(
            dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = (
            self.assemble_datasets())

    ############################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return (
            tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0])
             + self.domain_extrema[:, 0])

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, x):
        # input is (x)*n and the output is (T_s, T_f)*n
        # Initial condition is 1 fr T_s and t_f
        return torch.ones(len(x),2)
    
    def nonhomogeneous_dirichlet_bc(self, t):
        # from eq. 8 in the problem document
        return (3/(1+torch.exp(-200*(t-0.25))))+1


    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]

        u = -torch.exp(-np.pi ** 2 * t) * torch.sin(np.pi * x)
        return u

    ############################################################################
    # Function returning the input-output tensor required to
    # assemble the training set S_tb corresponding to the temporal boundary.
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))

        # Assigns the value t0 to every element of the first column of input_tb
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        # Creates a column vector containing the solution at each temporal boundary point,
        # based on the initial condition
        output_tb = self.initial_condition(input_tb[:, 1])

        # input_tb has points [t0,x], with x being taken across the whole spatial domain
        # output_tb has points [u_S, u_f], the value of the initial condition at the corresponding
        # spatial coordinate
        return input_tb, output_tb

    # Function returning the input-output tensor required to
    # assemble the training set S_sb corresponding to the spatial boundary.
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        # spatial boundary conditions at the lower spatial extrema
        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        # spatial boundary conditions at the upper spatial extrema
        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        # value of the solution at the lower spatial extrema
        # if the value is constrained by PDE only (eg. neumann BCs),
        # put 0
        output_sb_0 = torch.zeros((input_sb.shape[0], 2))
        # add non_homogeneous dirichlet BCs for T_f, passing the time column of the input
        output_sb_0[:,1] = self.nonhomogeneous_dirichlet_bc(input_sb_0[:, 0])

        # value of the solution at the upper spatial extrema
        # if the value is constrained by PDE only (eg. neumann BCs),
        # put 0
        output_sb_L = torch.zeros((input_sb.shape[0], 2))
        # augment 
        

        return (
            torch.cat([input_sb_0, input_sb_L], 0),
            torch.cat([output_sb_0, output_sb_L], 0)
        )

    # Function returning the input-output tensor required to assemble
    # the training set S_int corresponding to the interior domain
    # where the PDE is enforced.
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()   # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()         # S_int

        training_set_sb = DataLoader(
            torch.utils.data.TensorDataset(input_sb, output_sb),
            batch_size=2 * self.space_dimensions*self.n_sb, shuffle=False)
        training_set_tb = DataLoader(
            torch.utils.data.TensorDataset(input_tb, output_tb),
            batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(
            torch.utils.data.TensorDataset(input_int, output_int),
            batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ############################################################################
    # Function to compute the terms required in the definition of
    # the `TEMPORAL` boundary residual.
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition
    # of the `SPATIAL` boundary residual.
    def apply_boundary_conditions(self, input_sb):
        input_sb.requires_grad = True
        u_pred_sb = self.approximate_solution(input_sb)
        u=u_pred_sb.sum(0)
        T_s=u[0]
        T_f=u[1]
        grad_Ts_x = torch.autograd.grad(T_s, input_sb, create_graph=True)[0][:,0]
        grad_Tf_x = torch.autograd.grad(T_f, input_sb, create_graph=True)[0][:,1]

        return u_pred_sb, grad_Tf_x, grad_Ts_x

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)
        # `grad` computes the gradient of a SCALAR function `L` w.r.t
        # some input (n x m) tensor  [[x1, y1], ...,[xn ,yn]] (here `m` = 2).
        #
        # it returns grad_L = [[dL/dx1, dL/dy1]...,[dL/dxn, dL/dyn]]
        # NOTO: pytorch considers a tensor [u1, u2,u3, ... ,un] a vector
        # whereas `sum_u = u1 + u2 + u3 + u4 + ... + un` as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2], ...]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un) /dxi ==
        #  d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi == dui / dxi.

        # TODO: compute `grad_u` w.r.t (t, x) (time + 1D space).
        u=u.sum(0)
        T_s=u[0]
        T_f=u[1]
        grad_Ts = torch.autograd.grad(T_s, input_int, create_graph=True)[0]
        grad_Tf = torch.autograd.grad(T_f, input_int, create_graph=True)[0]


        # TODO: Extract time and space derivative at all input points.
        grad_Ts_t = grad_Ts[:,0]
        grad_Ts_x = grad_Ts[:,1]

        grad_Tf_t = grad_Tf[:,0]
        grad_Tf_x = grad_Tf[:,1]
        # TODO: Compute `grads` again across the spatial dimension --
        # here you should reuse something you just computed.
        grad_Tf_xx = torch.autograd.grad(
            grad_Tf_x.sum(),input_int, create_graph=True)[0][:,1]
        
        grad_Ts_xx = torch.autograd.grad(
            grad_Ts_x.sum(),input_int, create_graph=True)[0][:,1]

        # Compute the residual term you're getting.
        residual = grad_Tf_t+grad_Tf_x-0.05*grad_Tf_xx+5*(T_f-T_s)+grad_Ts_t-0.08*grad_Ts_xx-6*(T_f-T_s)
        return residual.reshape(-1,)

    # Function to compute the total loss (weighted sum of spatial boundary loss,
    # temporal boundary loss and interior loss).
    def compute_loss(
        self, inp_train_sb, u_train_sb,
        inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb, grad_Ts_sb, grad_Tf_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])

        # TODO: Compute interior PDE residual.
        r_int = self.compute_pde_residual(inp_train_int)

        # TOOD: Compute spatial boundary residual.
        num_sb_samples=u_train_sb.shape[0]
        r_sb=torch.zeros_like(u_train_sb)
        # Compute residual for dirichlet BCs
        # T_f at x_0
        r_sb[:num_sb_samples//2,1] = u_train_sb[:num_sb_samples//2,1] - u_pred_sb[:num_sb_samples//2,1]

        # Compute residual for neumann BCs
        # for T_s (x_0 and x_L)
        r_sb[:,0]=grad_Ts_sb
        # for T_f (x_L only)
        r_sb[num_sb_samples//2:,1]=grad_Tf_sb[num_sb_samples//2:]
        r_sb = r_sb.reshape(-1,)

        # TODO: Compute temporal boundary residual
        r_tb = u_train_tb - u_pred_tb
        r_tb = r_tb.reshape(-1,)

        # TODO: Compute losses based on these residuals.
        loss_sb = torch.mean(r_sb**2)
        loss_tb = torch.mean(r_tb**2)
        loss_int = torch.mean(r_int**2)

        loss_u = loss_sb + loss_tb
        loss = torch.log10(self.lambda_u * (loss_sb + loss_tb) + loss_int)
        if verbose:
            print(
               "Total loss: ",round(loss.item(), 4),
               "| PDE Loss: ", round(torch.log10(loss_u).item(), 4),
               "| Function Loss: ", round(torch.log10(loss_int).item(), 4)
          )

        return loss

    ############################################################################

    def fit(self, num_epochs, verbose):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose:
                print("################################ ",
                    epoch, " ################################")

            for j, inputs_and_outputs in enumerate(zip(self.training_set_sb,
                    self.training_set_tb,
                    self.training_set_int)):
                (
                      (inp_train_sb, u_train_sb),
                      (inp_train_tb, u_train_tb),
                      (inp_train_int, u_train_int)
                  ) = inputs_and_outputs

                def closure():
                    self.optimizer.zero_grad()
                    loss = self.compute_loss(
                        inp_train_sb,
                        u_train_sb,
                        inp_train_tb,
                        u_train_tb,
                        inp_train_int,
                        verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                self.optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ############################################################################
    def plot(self):
        inputs = self.soboleng.draw(100000)
        inputs = self.convert(inputs)

        output = self.approximate_solution(inputs).reshape(-1, )
        exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(
            inputs[:, 1].detach(), inputs[:, 0].detach(),
            c=exact_output.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(
            inputs[:, 1].detach(), inputs[:, 0].detach(), c=output.detach(),
            cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Solution")
        axs[1].set_title("Approximate Solution")

        plt.show()

        err = (
            torch.mean((output - exact_output) ** 2) /
            torch.mean(exact_output ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm: ", err.item(), "%")

# %% [markdown]
# # Setting up the training data
#
# Just familiarize yourself with how wo generate collocation points for the different types of residuals.

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi * x).

n_int = 256
n_sb = 64
n_tb = 64

pinn = PINNTrainer(n_int, n_sb, n_tb)

# %%
# Plot the input training points.
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.scatter(
    input_sb_[:, 1].detach().numpy(),
    input_sb_[:, 0].detach().numpy(),
    label="Boundary Points")
plt.scatter(
    input_int_[:, 1].detach().numpy(),
    input_int_[:, 0].detach().numpy(),
    label="Interior Points")
plt.scatter(
    input_tb_[:, 1].detach().numpy(),
    input_tb_[:, 0].detach().numpy(),
    label="Initial Points")

plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %% [markdown]
# # Training
#
# Train your network and ensure your loss is low, and that your predictions are qualitatively similar to the true solution (plots should look similar).

# %%
hist = pinn.fit(num_epochs=10000, verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  3.7096 | PDE Loss:  0.5766 | Function Loss:  3.7064
# ################################  1  ################################
# Total loss:  3.5798 | PDE Loss:  0.5803 | Function Loss:  3.5754
# ################################  2  ################################
# Total loss:  3.4244 | PDE Loss:  0.5841 | Function Loss:  3.4181
# ################################  3  ################################
# Total loss:  3.2321 | PDE Loss:  0.5879 | Function Loss:  3.2222
# ################################  4  ################################
# Total loss:  2.9816 | PDE Loss:  0.5917 | Function Loss:  2.9635
# ################################  5  ################################
# Total loss:  2.6294 | PDE Loss:  0.5955 | Function Loss:  2.5872
# ################################  6  ################################
# Total loss:  2.0818 | PDE Loss:  0.5994 | Function Loss:  1.9083
# ################################  7  ################################
# Total loss:  1.6259 | PDE Loss:  0.6032 | Function Loss:  0.3324
# ################################  8  ################################
# Total loss:  2.0359 | PDE Loss:  0.6057 | Function Loss:  1.8343
# ################################  9  ################################
# Total loss:  2.1298 | PDE Loss:  0.6063 | Function Loss:  1.9752
# ################################  10  ################################
# Total loss:  2.0275 | PDE Loss:  0.6058 | Function Loss:  1.8207
# ################################  11  ################################
# Total loss:  1.7768 | PDE Loss:  0.6046 | Function Loss:  1.2918
# ################################  12  ################################
# Total loss:  1.6082 | PDE Loss:  0.6029 | Function Loss:  -0.3141
# ################################  13  ################################
# Total loss:  1.7951 | PDE Loss:  0.6016 | Function Loss:  1.351
# ################################  14  ################################
# Total loss:  1.8916 | PDE Loss:  0.601 | Function Loss:  1.5799
# ################################  15  ################################
# Total loss:  1.847 | PDE Loss:  0.6012 | Function Loss:  1.4825
# ################################  16  ################################
# Total loss:  1.702 | PDE Loss:  0.6019 | Function Loss:  1.0153
# ################################  17  ################################
# Total loss:  1.6034 | PDE Loss:  0.603 | Function Loss:  -1.5321
# ################################  18  ################################
# Total loss:  1.6999 | PDE Loss:  0.604 | Function Loss:  0.9971
# ################################  19  ################################
# Total loss:  1.7747 | PDE Loss:  0.6043 | Function Loss:  1.2861
# ################################  20  ################################
# Total loss:  1.7445 | PDE Loss:  0.604 | Function Loss:  1.186
# ################################  21  ################################
# Total loss:  1.647 | PDE Loss:  0.6033 | Function Loss:  0.6285
# ################################  22  ################################
# Total loss:  1.6052 | PDE Loss:  0.6023 | Function Loss:  -0.5666
# ################################  23  ################################
# Total loss:  1.6692 | PDE Loss:  0.6014 | Function Loss:  0.8294
# ################################  24  ################################
# Total loss:  1.7094 | PDE Loss:  0.601 | Function Loss:  1.0537
# ################################  25  ################################
# Total loss:  1.6786 | PDE Loss:  0.601 | Function Loss:  0.8921
# ################################  26  ################################
# Total loss:  1.6163 | PDE Loss:  0.6014 | Function Loss:  0.1432
# ################################  27  ################################
# Total loss:  1.6093 | PDE Loss:  0.6019 | Function Loss:  -0.1651
# ################################  28  ################################
# Total loss:  1.6539 | PDE Loss:  0.6022 | Function Loss:  0.7036
# ################################  29  ################################
# Total loss:  1.6672 | PDE Loss:  0.6021 | Function Loss:  0.8105
# ################################  30  ################################
# Total loss:  1.6332 | PDE Loss:  0.6016 | Function Loss:  0.4794
# ################################  31  ################################
# Total loss:  1.6015 | PDE Loss:  0.6009 | Function Loss:  -1.2998
# ################################  32  ################################
# Total loss:  1.6172 | PDE Loss:  0.6002 | Function Loss:  0.2025
# ################################  33  ################################
# Total loss:  1.6421 | PDE Loss:  0.5997 | Function Loss:  0.6112
# ################################  34  ################################
# Total loss:  1.6343 | PDE Loss:  0.5995 | Function Loss:  0.5202
# ################################  35  ################################
# Total loss:  1.607 | PDE Loss:  0.5996 | Function Loss:  -0.1652
# ################################  36  ################################
# Total loss:  1.6022 | PDE Loss:  0.5998 | Function Loss:  -0.6539
# ################################  37  ################################
# Total loss:  1.6211 | PDE Loss:  0.5999 | Function Loss:  0.2988
# ################################  38  ################################
# Total loss:  1.6259 | PDE Loss:  0.5997 | Function Loss:  0.394
# ################################  39  ################################
# Total loss:  1.6092 | PDE Loss:  0.5992 | Function Loss:  -0.0341
# ################################  40  ################################
# Total loss:  1.5986 | PDE Loss:  0.5985 | Function Loss:  -2.1876
# ################################  41  ################################
# Total loss:  1.6086 | PDE Loss:  0.5979 | Function Loss:  -0.0064
# ################################  42  ################################
# Total loss:  1.6164 | PDE Loss:  0.5975 | Function Loss:  0.2454
# ################################  43  ################################
# Total loss:  1.6077 | PDE Loss:  0.5973 | Function Loss:  -0.0204
# ################################  44  ################################
# Total loss:  1.5976 | PDE Loss:  0.5973 | Function Loss:  -1.5551
# ################################  45  ################################
# Total loss:  1.6019 | PDE Loss:  0.5973 | Function Loss:  -0.3725
# ################################  46  ################################
# Total loss:  1.6088 | PDE Loss:  0.5971 | Function Loss:  0.0334
# ################################  47  ################################
# Total loss:  1.6042 | PDE Loss:  0.5967 | Function Loss:  -0.1596
# ################################  48  ################################
# Total loss:  1.5965 | PDE Loss:  0.5961 | Function Loss:  -1.4527
# ################################  49  ################################
# Total loss:  1.5984 | PDE Loss:  0.5956 | Function Loss:  -0.5855
# ################################  50  ################################
# Total loss:  1.6033 | PDE Loss:  0.5951 | Function Loss:  -0.1215
# ################################  51  ################################
# Total loss:  1.6006 | PDE Loss:  0.5948 | Function Loss:  -0.2778
# ################################  52  ################################
# Total loss:  1.5951 | PDE Loss:  0.5946 | Function Loss:  -1.4018
# ################################  53  ################################
# Total loss:  1.5961 | PDE Loss:  0.5945 | Function Loss:  -0.8277
# ################################  54  ################################
# Total loss:  1.5994 | PDE Loss:  0.5942 | Function Loss:  -0.329
# ################################  55  ################################
# Total loss:  1.5971 | PDE Loss:  0.5938 | Function Loss:  -0.5197
# ################################  56  ################################
# Total loss:  1.5934 | PDE Loss:  0.5933 | Function Loss:  -2.0461
# ################################  57  ################################
# Total loss:  1.5944 | PDE Loss:  0.5927 | Function Loss:  -0.8301
# ################################  58  ################################
# Total loss:  1.5962 | PDE Loss:  0.5923 | Function Loss:  -0.4459
# ################################  59  ################################
# Total loss:  1.5941 | PDE Loss:  0.5919 | Function Loss:  -0.7091
# ################################  60  ################################
# Total loss:  1.5917 | PDE Loss:  0.5917 | Function Loss:  -2.8019
# ################################  61  ################################
# Total loss:  1.5927 | PDE Loss:  0.5914 | Function Loss:  -0.9341
# ################################  62  ################################
# Total loss:  1.5935 | PDE Loss:  0.5911 | Function Loss:  -0.669
# ################################  63  ################################
# Total loss:  1.5914 | PDE Loss:  0.5906 | Function Loss:  -1.1347
# ################################  64  ################################
# Total loss:  1.5902 | PDE Loss:  0.5901 | Function Loss:  -2.117
# ################################  65  ################################
# Total loss:  1.5911 | PDE Loss:  0.5896 | Function Loss:  -0.8721
# ################################  66  ################################
# Total loss:  1.5908 | PDE Loss:  0.5891 | Function Loss:  -0.8135
# ################################  67  ################################
# Total loss:  1.5891 | PDE Loss:  0.5888 | Function Loss:  -1.5471
# ################################  68  ################################
# Total loss:  1.5887 | PDE Loss:  0.5885 | Function Loss:  -1.7309
# ################################  69  ################################
# Total loss:  1.5892 | PDE Loss:  0.5881 | Function Loss:  -1.0164
# ################################  70  ################################
# Total loss:  1.5883 | PDE Loss:  0.5876 | Function Loss:  -1.2169
# ################################  71  ################################
# Total loss:  1.5871 | PDE Loss:  0.5871 | Function Loss:  -4.0825
# ################################  72  ################################
# Total loss:  1.5872 | PDE Loss:  0.5866 | Function Loss:  -1.2936
# ################################  73  ################################
# Total loss:  1.5871 | PDE Loss:  0.5861 | Function Loss:  -1.0728
# ################################  74  ################################
# Total loss:  1.586 | PDE Loss:  0.5857 | Function Loss:  -1.6132
# ################################  75  ################################
# Total loss:  1.5854 | PDE Loss:  0.5853 | Function Loss:  -2.3532
# ################################  76  ################################
# Total loss:  1.5854 | PDE Loss:  0.5849 | Function Loss:  -1.3609
# ################################  77  ################################
# Total loss:  1.5848 | PDE Loss:  0.5844 | Function Loss:  -1.5216
# ################################  78  ################################
# Total loss:  1.5839 | PDE Loss:  0.5839 | Function Loss:  -4.6163
# ################################  79  ################################
# Total loss:  1.5837 | PDE Loss:  0.5834 | Function Loss:  -1.5479
# ################################  80  ################################
# Total loss:  1.5834 | PDE Loss:  0.5829 | Function Loss:  -1.3649
# ################################  81  ################################
# Total loss:  1.5825 | PDE Loss:  0.5824 | Function Loss:  -2.0166
# ################################  82  ################################
# Total loss:  1.582 | PDE Loss:  0.582 | Function Loss:  -2.3781
# ################################  83  ################################
# Total loss:  1.5818 | PDE Loss:  0.5815 | Function Loss:  -1.6519
# ################################  84  ################################
# Total loss:  1.5811 | PDE Loss:  0.581 | Function Loss:  -2.0348
# ################################  85  ################################
# Total loss:  1.5805 | PDE Loss:  0.5805 | Function Loss:  -2.7538
# ################################  86  ################################
# Total loss:  1.5801 | PDE Loss:  0.5799 | Function Loss:  -1.6683
# ################################  87  ################################
# Total loss:  1.5796 | PDE Loss:  0.5794 | Function Loss:  -1.7313
# ################################  88  ################################
# Total loss:  1.5789 | PDE Loss:  0.5789 | Function Loss:  -3.0705
# ################################  89  ################################
# Total loss:  1.5785 | PDE Loss:  0.5784 | Function Loss:  -2.2022
# ################################  90  ################################
# Total loss:  1.578 | PDE Loss:  0.5779 | Function Loss:  -2.0254
# ################################  91  ################################
# Total loss:  1.5773 | PDE Loss:  0.5773 | Function Loss:  -3.4943
# ################################  92  ################################
# Total loss:  1.5768 | PDE Loss:  0.5768 | Function Loss:  -2.1485
# ################################  93  ################################
# Total loss:  1.5764 | PDE Loss:  0.5762 | Function Loss:  -1.8577
# ################################  94  ################################
# Total loss:  1.5757 | PDE Loss:  0.5757 | Function Loss:  -2.4443
# ################################  95  ################################
# Total loss:  1.5752 | PDE Loss:  0.5751 | Function Loss:  -3.0018
# ################################  96  ################################
# Total loss:  1.5747 | PDE Loss:  0.5746 | Function Loss:  -2.294
# ################################  97  ################################
# Total loss:  1.574 | PDE Loss:  0.574 | Function Loss:  -3.0857
# ################################  98  ################################
# Total loss:  1.5734 | PDE Loss:  0.5734 | Function Loss:  -2.5681
# ################################  99  ################################
# Total loss:  1.5729 | PDE Loss:  0.5728 | Function Loss:  -2.0722
# ################################  100  ################################
# Total loss:  1.5723 | PDE Loss:  0.5722 | Function Loss:  -2.4689
# ################################  101  ################################
# Total loss:  1.5717 | PDE Loss:  0.5717 | Function Loss:  -3.7709
# ################################  102  ################################
# Total loss:  1.5711 | PDE Loss:  0.5711 | Function Loss:  -2.6292
# ################################  103  ################################
# Total loss:  1.5705 | PDE Loss:  0.5705 | Function Loss:  -3.4298
# ################################  104  ################################
# Total loss:  1.5699 | PDE Loss:  0.5698 | Function Loss:  -2.7288
# ################################  105  ################################
# Total loss:  1.5693 | PDE Loss:  0.5692 | Function Loss:  -2.2739
# ################################  106  ################################
# Total loss:  1.5686 | PDE Loss:  0.5686 | Function Loss:  -2.7096
# ################################  107  ################################
# Total loss:  1.568 | PDE Loss:  0.568 | Function Loss:  -3.8855
# ################################  108  ################################
# Total loss:  1.5674 | PDE Loss:  0.5674 | Function Loss:  -2.9898
# ################################  109  ################################
# Total loss:  1.5667 | PDE Loss:  0.5667 | Function Loss:  -4.4638
# ################################  110  ################################
# Total loss:  1.5661 | PDE Loss:  0.566 | Function Loss:  -2.6811
# ################################  111  ################################
# Total loss:  1.5654 | PDE Loss:  0.5654 | Function Loss:  -2.4808
# ################################  112  ################################
# Total loss:  1.5647 | PDE Loss:  0.5647 | Function Loss:  -3.1928
# ################################  113  ################################
# Total loss:  1.5641 | PDE Loss:  0.5641 | Function Loss:  -3.6617
# ################################  114  ################################
# Total loss:  1.5634 | PDE Loss:  0.5634 | Function Loss:  -3.5931
# ################################  115  ################################
# Total loss:  1.5627 | PDE Loss:  0.5627 | Function Loss:  -3.3869
# ################################  116  ################################
# Total loss:  1.562 | PDE Loss:  0.562 | Function Loss:  -2.6383
# ################################  117  ################################
# Total loss:  1.5613 | PDE Loss:  0.5613 | Function Loss:  -2.8241
# ################################  118  ################################
# Total loss:  1.5606 | PDE Loss:  0.5606 | Function Loss:  -4.1813
# ################################  119  ################################
# Total loss:  1.5599 | PDE Loss:  0.5599 | Function Loss:  -3.7762
# ################################  120  ################################
# Total loss:  1.5591 | PDE Loss:  0.5591 | Function Loss:  -4.0124
# ################################  121  ################################
# Total loss:  1.5584 | PDE Loss:  0.5584 | Function Loss:  -2.8773
# ################################  122  ################################
# Total loss:  1.5577 | PDE Loss:  0.5576 | Function Loss:  -2.8111
# ################################  123  ################################
# Total loss:  1.5569 | PDE Loss:  0.5569 | Function Loss:  -3.589
# ################################  124  ################################
# Total loss:  1.5562 | PDE Loss:  0.5562 | Function Loss:  -4.1753
# ################################  125  ################################
# Total loss:  1.5554 | PDE Loss:  0.5554 | Function Loss:  -4.1052
# ################################  126  ################################
# Total loss:  1.5546 | PDE Loss:  0.5546 | Function Loss:  -3.042
# ################################  127  ################################
# Total loss:  1.5538 | PDE Loss:  0.5538 | Function Loss:  -2.8927
# ################################  128  ################################
# Total loss:  1.553 | PDE Loss:  0.553 | Function Loss:  -3.484
# ################################  129  ################################
# Total loss:  1.5522 | PDE Loss:  0.5522 | Function Loss:  -4.2604
# ################################  130  ################################
# Total loss:  1.5514 | PDE Loss:  0.5514 | Function Loss:  -3.904
# ################################  131  ################################
# Total loss:  1.5506 | PDE Loss:  0.5506 | Function Loss:  -3.0879
# ################################  132  ################################
# Total loss:  1.5498 | PDE Loss:  0.5498 | Function Loss:  -3.0021
# ################################  133  ################################
# Total loss:  1.5489 | PDE Loss:  0.5489 | Function Loss:  -3.5716
# ################################  134  ################################
# Total loss:  1.5481 | PDE Loss:  0.5481 | Function Loss:  -4.1157
# ################################  135  ################################
# Total loss:  1.5472 | PDE Loss:  0.5472 | Function Loss:  -3.608
# ################################  136  ################################
# Total loss:  1.5464 | PDE Loss:  0.5464 | Function Loss:  -3.0718
# ################################  137  ################################
# Total loss:  1.5455 | PDE Loss:  0.5455 | Function Loss:  -3.1555
# ################################  138  ################################
# Total loss:  1.5446 | PDE Loss:  0.5446 | Function Loss:  -3.7359
# ################################  139  ################################
# Total loss:  1.5437 | PDE Loss:  0.5437 | Function Loss:  -3.8793
# ################################  140  ################################
# Total loss:  1.5428 | PDE Loss:  0.5428 | Function Loss:  -3.3253
# ################################  141  ################################
# Total loss:  1.5419 | PDE Loss:  0.5419 | Function Loss:  -3.0939
# ################################  142  ################################
# Total loss:  1.541 | PDE Loss:  0.541 | Function Loss:  -3.398
# ################################  143  ################################
# Total loss:  1.54 | PDE Loss:  0.54 | Function Loss:  -3.796
# ################################  144  ################################
# Total loss:  1.5391 | PDE Loss:  0.5391 | Function Loss:  -3.5236
# ################################  145  ################################
# Total loss:  1.5381 | PDE Loss:  0.5381 | Function Loss:  -3.1591
# ################################  146  ################################
# Total loss:  1.5372 | PDE Loss:  0.5371 | Function Loss:  -3.2595
# ################################  147  ################################
# Total loss:  1.5362 | PDE Loss:  0.5362 | Function Loss:  -3.6384
# ################################  148  ################################
# Total loss:  1.5352 | PDE Loss:  0.5352 | Function Loss:  -3.5792
# ################################  149  ################################
# Total loss:  1.5342 | PDE Loss:  0.5342 | Function Loss:  -3.2283
# ################################  150  ################################
# Total loss:  1.5332 | PDE Loss:  0.5332 | Function Loss:  -3.2255
# ################################  151  ################################
# Total loss:  1.5322 | PDE Loss:  0.5321 | Function Loss:  -3.5325
# ################################  152  ################################
# Total loss:  1.5311 | PDE Loss:  0.5311 | Function Loss:  -3.5476
# ################################  153  ################################
# Total loss:  1.5301 | PDE Loss:  0.5301 | Function Loss:  -3.2549
# ################################  154  ################################
# Total loss:  1.529 | PDE Loss:  0.529 | Function Loss:  -3.2329
# ################################  155  ################################
# Total loss:  1.528 | PDE Loss:  0.528 | Function Loss:  -3.4833
# ################################  156  ################################
# Total loss:  1.5269 | PDE Loss:  0.5269 | Function Loss:  -3.4821
# ################################  157  ################################
# Total loss:  1.5258 | PDE Loss:  0.5258 | Function Loss:  -3.2432
# ################################  158  ################################
# Total loss:  1.5247 | PDE Loss:  0.5247 | Function Loss:  -3.2589
# ################################  159  ################################
# Total loss:  1.5236 | PDE Loss:  0.5236 | Function Loss:  -3.4626
# ################################  160  ################################
# Total loss:  1.5225 | PDE Loss:  0.5225 | Function Loss:  -3.397
# ################################  161  ################################
# Total loss:  1.5213 | PDE Loss:  0.5213 | Function Loss:  -3.2189
# ################################  162  ################################
# Total loss:  1.5202 | PDE Loss:  0.5202 | Function Loss:  -3.3033
# ################################  163  ################################
# Total loss:  1.519 | PDE Loss:  0.519 | Function Loss:  -3.4317
# ################################  164  ################################
# Total loss:  1.5179 | PDE Loss:  0.5179 | Function Loss:  -3.2983
# ################################  165  ################################
# Total loss:  1.5167 | PDE Loss:  0.5167 | Function Loss:  -3.2177
# ################################  166  ################################
# Total loss:  1.5155 | PDE Loss:  0.5155 | Function Loss:  -3.3511
# ################################  167  ################################
# Total loss:  1.5143 | PDE Loss:  0.5143 | Function Loss:  -3.3551
# ################################  168  ################################
# Total loss:  1.5131 | PDE Loss:  0.5131 | Function Loss:  -3.2177
# ################################  169  ################################
# Total loss:  1.5119 | PDE Loss:  0.5119 | Function Loss:  -3.2645
# ################################  170  ################################
# Total loss:  1.5106 | PDE Loss:  0.5106 | Function Loss:  -3.3468
# ################################  171  ################################
# Total loss:  1.5094 | PDE Loss:  0.5094 | Function Loss:  -3.2414
# ################################  172  ################################
# Total loss:  1.5081 | PDE Loss:  0.5081 | Function Loss:  -3.2137
# ################################  173  ################################
# Total loss:  1.5069 | PDE Loss:  0.5069 | Function Loss:  -3.3075
# ################################  174  ################################
# Total loss:  1.5056 | PDE Loss:  0.5056 | Function Loss:  -3.2502
# ################################  175  ################################
# Total loss:  1.5043 | PDE Loss:  0.5043 | Function Loss:  -3.1884
# ################################  176  ################################
# Total loss:  1.503 | PDE Loss:  0.503 | Function Loss:  -3.2665
# ################################  177  ################################
# Total loss:  1.5017 | PDE Loss:  0.5017 | Function Loss:  -3.2391
# ################################  178  ################################
# Total loss:  1.5004 | PDE Loss:  0.5003 | Function Loss:  -3.1717
# ################################  179  ################################
# Total loss:  1.499 | PDE Loss:  0.499 | Function Loss:  -3.234
# ################################  180  ################################
# Total loss:  1.4977 | PDE Loss:  0.4977 | Function Loss:  -3.2143
# ################################  181  ################################
# Total loss:  1.4963 | PDE Loss:  0.4963 | Function Loss:  -3.1554
# ################################  182  ################################
# Total loss:  1.495 | PDE Loss:  0.4949 | Function Loss:  -3.2088
# ################################  183  ################################
# Total loss:  1.4936 | PDE Loss:  0.4936 | Function Loss:  -3.1815
# ################################  184  ################################
# Total loss:  1.4922 | PDE Loss:  0.4922 | Function Loss:  -3.1391
# ################################  185  ################################
# Total loss:  1.4908 | PDE Loss:  0.4908 | Function Loss:  -3.187
# ################################  186  ################################
# Total loss:  1.4894 | PDE Loss:  0.4894 | Function Loss:  -3.142
# ################################  187  ################################
# Total loss:  1.488 | PDE Loss:  0.4879 | Function Loss:  -3.1289
# ################################  188  ################################
# Total loss:  1.4865 | PDE Loss:  0.4865 | Function Loss:  -3.1588
# ################################  189  ################################
# Total loss:  1.4851 | PDE Loss:  0.4851 | Function Loss:  -3.1025
# ################################  190  ################################
# Total loss:  1.4836 | PDE Loss:  0.4836 | Function Loss:  -3.1261
# ################################  191  ################################
# Total loss:  1.4822 | PDE Loss:  0.4822 | Function Loss:  -3.1138
# ################################  192  ################################
# Total loss:  1.4807 | PDE Loss:  0.4807 | Function Loss:  -3.0818
# ################################  193  ################################
# Total loss:  1.4792 | PDE Loss:  0.4792 | Function Loss:  -3.1115
# ################################  194  ################################
# Total loss:  1.4777 | PDE Loss:  0.4777 | Function Loss:  -3.0625
# ################################  195  ################################
# Total loss:  1.4762 | PDE Loss:  0.4762 | Function Loss:  -3.085
# ################################  196  ################################
# Total loss:  1.4747 | PDE Loss:  0.4747 | Function Loss:  -3.0597
# ################################  197  ################################
# Total loss:  1.4732 | PDE Loss:  0.4732 | Function Loss:  -3.0517
# ################################  198  ################################
# Total loss:  1.4717 | PDE Loss:  0.4717 | Function Loss:  -3.0561
# ################################  199  ################################
# Total loss:  1.4701 | PDE Loss:  0.4701 | Function Loss:  -3.0216
# ################################  200  ################################
# Total loss:  1.4686 | PDE Loss:  0.4686 | Function Loss:  -3.049
# ################################  201  ################################
# Total loss:  1.4671 | PDE Loss:  0.467 | Function Loss:  -2.992
# ################################  202  ################################
# Total loss:  1.4655 | PDE Loss:  0.4655 | Function Loss:  -3.045
# ################################  203  ################################
# Total loss:  1.4639 | PDE Loss:  0.4639 | Function Loss:  -2.9507
# ################################  204  ################################
# Total loss:  1.4624 | PDE Loss:  0.4623 | Function Loss:  -3.0587
# ################################  205  ################################
# Total loss:  1.4608 | PDE Loss:  0.4608 | Function Loss:  -2.8616
# ################################  206  ################################
# Total loss:  1.4592 | PDE Loss:  0.4592 | Function Loss:  -3.0983
# ################################  207  ################################
# Total loss:  1.4576 | PDE Loss:  0.4576 | Function Loss:  -2.6049
# ################################  208  ################################
# Total loss:  1.456 | PDE Loss:  0.456 | Function Loss:  -2.7741
# ################################  209  ################################
# Total loss:  1.4545 | PDE Loss:  0.4543 | Function Loss:  -1.9387
# ################################  210  ################################
# Total loss:  1.4532 | PDE Loss:  0.4528 | Function Loss:  -1.5956
# ################################  211  ################################
# Total loss:  1.453 | PDE Loss:  0.451 | Function Loss:  -0.8746
# ################################  212  ################################
# Total loss:  1.4566 | PDE Loss:  0.4499 | Function Loss:  -0.3554
# ################################  213  ################################
# Total loss:  1.467 | PDE Loss:  0.4475 | Function Loss:  0.1086
# ################################  214  ################################
# Total loss:  1.4693 | PDE Loss:  0.4473 | Function Loss:  0.163
# ################################  215  ################################
# Total loss:  1.4511 | PDE Loss:  0.4451 | Function Loss:  -0.4139
# ################################  216  ################################
# Total loss:  1.4457 | PDE Loss:  0.444 | Function Loss:  -0.9633
# ################################  217  ################################
# Total loss:  1.4568 | PDE Loss:  0.4433 | Function Loss:  -0.0577
# ################################  218  ################################
# Total loss:  1.452 | PDE Loss:  0.4412 | Function Loss:  -0.1601
# ################################  219  ################################
# Total loss:  1.4405 | PDE Loss:  0.4404 | Function Loss:  -2.5161
# ################################  220  ################################
# Total loss:  1.4462 | PDE Loss:  0.4395 | Function Loss:  -0.3726
# ################################  221  ################################
# Total loss:  1.4478 | PDE Loss:  0.4376 | Function Loss:  -0.1876
# ################################  222  ################################
# Total loss:  1.4378 | PDE Loss:  0.437 | Function Loss:  -1.2957
# ################################  223  ################################
# Total loss:  1.4389 | PDE Loss:  0.4359 | Function Loss:  -0.7238
# ################################  224  ################################
# Total loss:  1.4424 | PDE Loss:  0.4341 | Function Loss:  -0.2854
# ################################  225  ################################
# Total loss:  1.4351 | PDE Loss:  0.4335 | Function Loss:  -0.9922
# ################################  226  ################################
# Total loss:  1.4334 | PDE Loss:  0.4323 | Function Loss:  -1.1653
# ################################  227  ################################
# Total loss:  1.4368 | PDE Loss:  0.4307 | Function Loss:  -0.4198
# ################################  228  ################################
# Total loss:  1.4324 | PDE Loss:  0.4301 | Function Loss:  -0.8543
# ################################  229  ################################
# Total loss:  1.429 | PDE Loss:  0.4288 | Function Loss:  -1.8946
# ################################  230  ################################
# Total loss:  1.4315 | PDE Loss:  0.4274 | Function Loss:  -0.5972
# ################################  231  ################################
# Total loss:  1.4293 | PDE Loss:  0.4267 | Function Loss:  -0.7912
# ################################  232  ################################
# Total loss:  1.4254 | PDE Loss:  0.4254 | Function Loss:  -2.6355
# ################################  233  ################################
# Total loss:  1.4264 | PDE Loss:  0.4241 | Function Loss:  -0.8518
# ################################  234  ################################
# Total loss:  1.426 | PDE Loss:  0.4234 | Function Loss:  -0.7946
# ################################  235  ################################
# Total loss:  1.4224 | PDE Loss:  0.422 | Function Loss:  -1.5919
# ################################  236  ################################
# Total loss:  1.4217 | PDE Loss:  0.4208 | Function Loss:  -1.2687
# ################################  237  ################################
# Total loss:  1.4221 | PDE Loss:  0.42 | Function Loss:  -0.888
# ################################  238  ################################
# Total loss:  1.4197 | PDE Loss:  0.4186 | Function Loss:  -1.1858
# ################################  239  ################################
# Total loss:  1.4177 | PDE Loss:  0.4176 | Function Loss:  -2.16
# ################################  240  ################################
# Total loss:  1.4179 | PDE Loss:  0.4167 | Function Loss:  -1.1329
# ################################  241  ################################
# Total loss:  1.4168 | PDE Loss:  0.4153 | Function Loss:  -1.0345
# ################################  242  ################################
# Total loss:  1.4145 | PDE Loss:  0.4144 | Function Loss:  -2.1633
# ################################  243  ################################
# Total loss:  1.4137 | PDE Loss:  0.4134 | Function Loss:  -1.71
# ################################  244  ################################
# Total loss:  1.4134 | PDE Loss:  0.4121 | Function Loss:  -1.0961
# ################################  245  ################################
# Total loss:  1.4118 | PDE Loss:  0.4112 | Function Loss:  -1.4683
# ################################  246  ################################
# Total loss:  1.4101 | PDE Loss:  0.41 | Function Loss:  -2.6912
# ################################  247  ################################
# Total loss:  1.4095 | PDE Loss:  0.4089 | Function Loss:  -1.458
# ################################  248  ################################
# Total loss:  1.4088 | PDE Loss:  0.408 | Function Loss:  -1.352
# ################################  249  ################################
# Total loss:  1.4072 | PDE Loss:  0.4068 | Function Loss:  -1.6021
# ################################  250  ################################
# Total loss:  1.4058 | PDE Loss:  0.4058 | Function Loss:  -2.5598
# ################################  251  ################################
# Total loss:  1.4052 | PDE Loss:  0.4048 | Function Loss:  -1.7051
# ################################  252  ################################
# Total loss:  1.4043 | PDE Loss:  0.4036 | Function Loss:  -1.3849
# ################################  253  ################################
# Total loss:  1.4029 | PDE Loss:  0.4027 | Function Loss:  -1.9395
# ################################  254  ################################
# Total loss:  1.4016 | PDE Loss:  0.4016 | Function Loss:  -2.7745
# ################################  255  ################################
# Total loss:  1.4008 | PDE Loss:  0.4005 | Function Loss:  -1.7261
# ################################  256  ################################
# Total loss:  1.4 | PDE Loss:  0.3996 | Function Loss:  -1.6793
# ################################  257  ################################
# Total loss:  1.3988 | PDE Loss:  0.3985 | Function Loss:  -1.7492
# ################################  258  ################################
# Total loss:  1.3975 | PDE Loss:  0.3975 | Function Loss:  -2.761
# ################################  259  ################################
# Total loss:  1.3966 | PDE Loss:  0.3965 | Function Loss:  -2.3145
# ################################  260  ################################
# Total loss:  1.3958 | PDE Loss:  0.3954 | Function Loss:  -1.6908
# ################################  261  ################################
# Total loss:  1.3947 | PDE Loss:  0.3945 | Function Loss:  -1.9358
# ################################  262  ################################
# Total loss:  1.3935 | PDE Loss:  0.3934 | Function Loss:  -2.1477
# ################################  263  ################################
# Total loss:  1.3925 | PDE Loss:  0.3924 | Function Loss:  -2.5699
# ################################  264  ################################
# Total loss:  1.3916 | PDE Loss:  0.3915 | Function Loss:  -2.2532
# ################################  265  ################################
# Total loss:  1.3907 | PDE Loss:  0.3904 | Function Loss:  -1.8158
# ################################  266  ################################
# Total loss:  1.3896 | PDE Loss:  0.3895 | Function Loss:  -2.1658
# ################################  267  ################################
# Total loss:  1.3886 | PDE Loss:  0.3885 | Function Loss:  -2.3185
# ################################  268  ################################
# Total loss:  1.3876 | PDE Loss:  0.3875 | Function Loss:  -2.5711
# ################################  269  ################################
# Total loss:  1.3866 | PDE Loss:  0.3866 | Function Loss:  -2.4163
# ################################  270  ################################
# Total loss:  1.3857 | PDE Loss:  0.3855 | Function Loss:  -1.9672
# ################################  271  ################################
# Total loss:  1.3847 | PDE Loss:  0.3847 | Function Loss:  -2.2807
# ################################  272  ################################
# Total loss:  1.3837 | PDE Loss:  0.3836 | Function Loss:  -2.2781
# ################################  273  ################################
# Total loss:  1.3827 | PDE Loss:  0.3827 | Function Loss:  -2.712
# ################################  274  ################################
# Total loss:  1.3818 | PDE Loss:  0.3818 | Function Loss:  -2.6663
# ################################  275  ################################
# Total loss:  1.3809 | PDE Loss:  0.3808 | Function Loss:  -2.1647
# ################################  276  ################################
# Total loss:  1.38 | PDE Loss:  0.3799 | Function Loss:  -2.3742
# ################################  277  ################################
# Total loss:  1.379 | PDE Loss:  0.3789 | Function Loss:  -2.1921
# ################################  278  ################################
# Total loss:  1.3781 | PDE Loss:  0.378 | Function Loss:  -2.6663
# ################################  279  ################################
# Total loss:  1.3771 | PDE Loss:  0.3771 | Function Loss:  -2.6544
# ################################  280  ################################
# Total loss:  1.3762 | PDE Loss:  0.3762 | Function Loss:  -2.4957
# ################################  281  ################################
# Total loss:  1.3754 | PDE Loss:  0.3753 | Function Loss:  -2.5932
# ################################  282  ################################
# Total loss:  1.3745 | PDE Loss:  0.3744 | Function Loss:  -2.2391
# ################################  283  ################################
# Total loss:  1.3736 | PDE Loss:  0.3735 | Function Loss:  -2.5411
# ################################  284  ################################
# Total loss:  1.3727 | PDE Loss:  0.3726 | Function Loss:  -2.3685
# ################################  285  ################################
# Total loss:  1.3717 | PDE Loss:  0.3717 | Function Loss:  -2.7133
# ################################  286  ################################
# Total loss:  1.3709 | PDE Loss:  0.3708 | Function Loss:  -2.671
# ################################  287  ################################
# Total loss:  1.37 | PDE Loss:  0.3699 | Function Loss:  -2.5475
# ################################  288  ################################
# Total loss:  1.3691 | PDE Loss:  0.3691 | Function Loss:  -2.6739
# ################################  289  ################################
# Total loss:  1.3683 | PDE Loss:  0.3682 | Function Loss:  -2.3696
# ################################  290  ################################
# Total loss:  1.3674 | PDE Loss:  0.3674 | Function Loss:  -2.6264
# ################################  291  ################################
# Total loss:  1.3665 | PDE Loss:  0.3665 | Function Loss:  -2.4081
# ################################  292  ################################
# Total loss:  1.3657 | PDE Loss:  0.3656 | Function Loss:  -2.6975
# ################################  293  ################################
# Total loss:  1.3648 | PDE Loss:  0.3648 | Function Loss:  -2.5833
# ################################  294  ################################
# Total loss:  1.364 | PDE Loss:  0.364 | Function Loss:  -2.6741
# ################################  295  ################################
# Total loss:  1.3632 | PDE Loss:  0.3631 | Function Loss:  -2.7042
# ################################  296  ################################
# Total loss:  1.3623 | PDE Loss:  0.3623 | Function Loss:  -2.5387
# ################################  297  ################################
# Total loss:  1.3615 | PDE Loss:  0.3615 | Function Loss:  -2.6953
# ################################  298  ################################
# Total loss:  1.3607 | PDE Loss:  0.3606 | Function Loss:  -2.4641
# ################################  299  ################################
# Total loss:  1.3599 | PDE Loss:  0.3598 | Function Loss:  -2.685
# ################################  300  ################################
# Total loss:  1.3591 | PDE Loss:  0.359 | Function Loss:  -2.4879
# ################################  301  ################################
# Total loss:  1.3583 | PDE Loss:  0.3582 | Function Loss:  -2.7052
# ################################  302  ################################
# Total loss:  1.3575 | PDE Loss:  0.3574 | Function Loss:  -2.5744
# ################################  303  ################################
# Total loss:  1.3567 | PDE Loss:  0.3566 | Function Loss:  -2.6991
# ################################  304  ################################
# Total loss:  1.3559 | PDE Loss:  0.3559 | Function Loss:  -2.6619
# ################################  305  ################################
# Total loss:  1.3551 | PDE Loss:  0.3551 | Function Loss:  -2.6437
# ################################  306  ################################
# Total loss:  1.3543 | PDE Loss:  0.3543 | Function Loss:  -2.704
# ################################  307  ################################
# Total loss:  1.3536 | PDE Loss:  0.3535 | Function Loss:  -2.583
# ################################  308  ################################
# Total loss:  1.3528 | PDE Loss:  0.3528 | Function Loss:  -2.7105
# ################################  309  ################################
# Total loss:  1.3521 | PDE Loss:  0.352 | Function Loss:  -2.5542
# ################################  310  ################################
# Total loss:  1.3513 | PDE Loss:  0.3513 | Function Loss:  -2.7107
# ################################  311  ################################
# Total loss:  1.3506 | PDE Loss:  0.3505 | Function Loss:  -2.5624
# ################################  312  ################################
# Total loss:  1.3498 | PDE Loss:  0.3498 | Function Loss:  -2.7124
# ################################  313  ################################
# Total loss:  1.3491 | PDE Loss:  0.349 | Function Loss:  -2.5974
# ################################  314  ################################
# Total loss:  1.3483 | PDE Loss:  0.3483 | Function Loss:  -2.7071
# ################################  315  ################################
# Total loss:  1.3476 | PDE Loss:  0.3476 | Function Loss:  -2.6407
# ################################  316  ################################
# Total loss:  1.3469 | PDE Loss:  0.3469 | Function Loss:  -2.6891
# ################################  317  ################################
# Total loss:  1.3462 | PDE Loss:  0.3461 | Function Loss:  -2.6764
# ################################  318  ################################
# Total loss:  1.3455 | PDE Loss:  0.3454 | Function Loss:  -2.664
# ################################  319  ################################
# Total loss:  1.3448 | PDE Loss:  0.3447 | Function Loss:  -2.6988
# ################################  320  ################################
# Total loss:  1.3441 | PDE Loss:  0.344 | Function Loss:  -2.6411
# ################################  321  ################################
# Total loss:  1.3434 | PDE Loss:  0.3433 | Function Loss:  -2.7106
# ################################  322  ################################
# Total loss:  1.3427 | PDE Loss:  0.3426 | Function Loss:  -2.6286
# ################################  323  ################################
# Total loss:  1.342 | PDE Loss:  0.342 | Function Loss:  -2.7151
# ################################  324  ################################
# Total loss:  1.3413 | PDE Loss:  0.3413 | Function Loss:  -2.631
# ################################  325  ################################
# Total loss:  1.3406 | PDE Loss:  0.3406 | Function Loss:  -2.715
# ################################  326  ################################
# Total loss:  1.34 | PDE Loss:  0.3399 | Function Loss:  -2.6457
# ################################  327  ################################
# Total loss:  1.3393 | PDE Loss:  0.3393 | Function Loss:  -2.71
# ################################  328  ################################
# Total loss:  1.3386 | PDE Loss:  0.3386 | Function Loss:  -2.6677
# ################################  329  ################################
# Total loss:  1.338 | PDE Loss:  0.3379 | Function Loss:  -2.6992
# ################################  330  ################################
# Total loss:  1.3373 | PDE Loss:  0.3373 | Function Loss:  -2.6895
# ################################  331  ################################
# Total loss:  1.3367 | PDE Loss:  0.3366 | Function Loss:  -2.6858
# ################################  332  ################################
# Total loss:  1.336 | PDE Loss:  0.336 | Function Loss:  -2.7058
# ################################  333  ################################
# Total loss:  1.3354 | PDE Loss:  0.3354 | Function Loss:  -2.6754
# ################################  334  ################################
# Total loss:  1.3348 | PDE Loss:  0.3347 | Function Loss:  -2.7153
# ################################  335  ################################
# Total loss:  1.3341 | PDE Loss:  0.3341 | Function Loss:  -2.6727
# ################################  336  ################################
# Total loss:  1.3335 | PDE Loss:  0.3335 | Function Loss:  -2.7188
# ################################  337  ################################
# Total loss:  1.3329 | PDE Loss:  0.3329 | Function Loss:  -2.6792
# ################################  338  ################################
# Total loss:  1.3323 | PDE Loss:  0.3323 | Function Loss:  -2.7174
# ################################  339  ################################
# Total loss:  1.3317 | PDE Loss:  0.3316 | Function Loss:  -2.6923
# ################################  340  ################################
# Total loss:  1.3311 | PDE Loss:  0.331 | Function Loss:  -2.7111
# ################################  341  ################################
# Total loss:  1.3305 | PDE Loss:  0.3304 | Function Loss:  -2.708
# ################################  342  ################################
# Total loss:  1.3299 | PDE Loss:  0.3298 | Function Loss:  -2.7029
# ################################  343  ################################
# Total loss:  1.3293 | PDE Loss:  0.3293 | Function Loss:  -2.7206
# ################################  344  ################################
# Total loss:  1.3287 | PDE Loss:  0.3287 | Function Loss:  -2.6986
# ################################  345  ################################
# Total loss:  1.3281 | PDE Loss:  0.3281 | Function Loss:  -2.7273
# ################################  346  ################################
# Total loss:  1.3275 | PDE Loss:  0.3275 | Function Loss:  -2.7017
# ################################  347  ################################
# Total loss:  1.327 | PDE Loss:  0.3269 | Function Loss:  -2.7282
# ################################  348  ################################
# Total loss:  1.3264 | PDE Loss:  0.3264 | Function Loss:  -2.7119
# ################################  349  ################################
# ...
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9822
# ################################  2952  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9811
# ################################  2953  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9813
# ################################  2954  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9827
# ################################  2955  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9804
# ################################  2956  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9818
# ################################  2957  ################################
# Total loss:  1.2215 | PDE Loss:  0.2215 | Function Loss:  -3.9819
# ################################  2958  ################################
# Total loss:  1.2215 | PDE Loss:  0.2214 | Function Loss:  -3.9821
# ################################  2959  ################################
# Total loss:  1.2215 | PDE Loss:  0.2214 | Function Loss:  -3.9823
# ################################  2960  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9824
# ################################  2961  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9838
# ################################  2962  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9815
# ################################  2963  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9829
# ################################  2964  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9806
# ################################  2965  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.982
# ################################  2966  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9834
# ################################  2967  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9835
# ################################  2968  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9825
# ################################  2969  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9851
# ################################  2970  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9816
# ################################  2971  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9842
# ################################  2972  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9831
# ################################  2973  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9845
# ################################  2974  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9846
# ################################  2975  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9836
# ################################  2976  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9849
# ################################  2977  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9839
# ################################  2978  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9853
# ################################  2979  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.983
# ################################  2980  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9844
# ################################  2981  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9845
# ################################  2982  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9822
# ################################  2983  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9836
# ################################  2984  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9838
# ################################  2985  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9827
# ################################  2986  ################################
# Total loss:  1.2214 | PDE Loss:  0.2214 | Function Loss:  -3.9841
# ################################  2987  ################################
# /home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:411: UserWarning: Error detected in TanhBackward0. Traceback of forward call that caused the error:
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_473260/2928184202.py", line 1, in <module>
#     hist = pinn.fit(num_epochs=10000, verbose=True)
#   File "/tmp/ipykernel_473260/792882697.py", line 286, in fit
#     self.optimizer.step(closure=closure)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/optimizer.py", line 385, in wrapper
#     out = func(*args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/optimizer.py", line 76, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/adam.py", line 146, in step
#     loss = closure()
#   File "/tmp/ipykernel_473260/792882697.py", line 274, in closure
#     loss = self.compute_loss(
#   File "/tmp/ipykernel_473260/792882697.py", line 211, in compute_loss
#     u_pred_sb, grad_Ts_sb, grad_Tf_sb = self.apply_boundary_conditions(inp_train_sb)
#   File "/tmp/ipykernel_473260/792882697.py", line 155, in apply_boundary_conditions
#     u_pred_sb = self.approximate_solution(input_sb)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_473260/3083261346.py", line 29, in forward
#     x=self.activation(self.output_layer(x))
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/patrick/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/nn/modules/activation.py", line 356, in forward
#     return torch.tanh(input)
#  (Triggered internally at ../torch/csrc/autograd/python_anomaly_mode.cpp:113.)
#   result = Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 hist = pinn.fit(num_epochs=10000, verbose=True)
#       3 plt.figure(dpi=150)
#       4 plt.grid(True, which="both", ls=":")
#
# Cell In[40], line 286, in PINNTrainer.fit(self, num_epochs, verbose)
#     283             history.append(loss.item())
#     284             return loss
# --> 286         self.optimizer.step(closure=closure)
#     288 print('Final Loss: ', history[-1])
#     290 return history
#
# File ~/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File ~/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/optim/adam.py:146, in Adam.step(self, closure)
#     144 if closure is not None:
#     145     with torch.enable_grad():
# --> 146         loss = closure()
#     148 for group in self.param_groups:
#     149     params_with_grad = []
#
# Cell In[40], line 274, in PINNTrainer.fit.<locals>.closure()
#     272 def closure():
#     273     self.optimizer.zero_grad()
# --> 274     loss = self.compute_loss(
#     275         inp_train_sb,
#     276         u_train_sb,
#     277         inp_train_tb,
#     278         u_train_tb,
#     279         inp_train_int,
#     280         verbose=verbose)
#     281     loss.backward()
#     283     history.append(loss.item())
#
# Cell In[40], line 211, in PINNTrainer.compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose)
#     208 def compute_loss(
#     209     self, inp_train_sb, u_train_sb,
#     210     inp_train_tb, u_train_tb, inp_train_int, verbose=True):
# --> 211     u_pred_sb, grad_Ts_sb, grad_Tf_sb = self.apply_boundary_conditions(inp_train_sb)
#     212     u_pred_tb = self.apply_initial_condition(inp_train_tb)
#     214     assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
#
# Cell In[40], line 160, in PINNTrainer.apply_boundary_conditions(self, input_sb)
#     158 T_f=u[1]
#     159 grad_Ts_x = torch.autograd.grad(T_s, input_sb, create_graph=True)[0][:,0]
# --> 160 grad_Tf_x = torch.autograd.grad(T_f, input_sb, create_graph=True)[0][:,1]
#     162 return u_pred_sb, grad_Tf_x, grad_Ts_x
#
# File ~/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:411, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     407     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     408         grad_outputs_
#     409     )
#     410 else:
# --> 411     result = Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     412         t_outputs,
#     413         grad_outputs_,
#     414         retain_graph,
#     415         create_graph,
#     416         inputs,
#     417         allow_unused,
#     418         accumulate_grad=False,
#     419     )  # Calls into the C++ engine to run the backward pass
#     420 if materialize_grads:
#     421     if any(
#     422         result[i] is None and not is_tensor_like(inputs[i])
#     423         for i in range(len(inputs))
#     424     ):
#
# File ~/Documents/ethz/24_spring/aise/src/venv/lib/python3.10/site-packages/torch/fx/traceback.py:68, in format_stack()
#      65     return [current_meta.get("stack_trace", "")]
#      66 else:
#      67     # fallback to traceback.format_stack()
# ---> 68     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File /usr/lib/python3.10/traceback.py:227, in extract_stack(f, limit)
#     225 if f is None:
#     226     f = sys._getframe().f_back
# --> 227 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     228 stack.reverse()
#     229 return stack
#
# File /usr/lib/python3.10/traceback.py:369, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     366 filename = co.co_filename
#     367 name = co.co_name
# --> 369 fnames.add(filename)
#     370 linecache.lazycache(filename, f.f_globals)
#     371 # Must defer line lookups until we have called checkcache.
#
# KeyboardInterrupt:

# %%
pinn.plot()
# Out:
# L2 Relative Error Norm:  2.416720151901245 %
